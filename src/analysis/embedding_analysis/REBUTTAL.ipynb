# %% [markdown]
# ## Import libraries

# %%
import os
import json

import numpy as np
from scipy.spatial.distance import euclidean, hamming
from scipy.stats import spearmanr, pearsonr

# %%
def read_memmap(filepath):
    with open(filepath.replace(".dat", ".conf"), "r") as fin_config:
        memmap_configs = json.load(fin_config)
        return np.memmap(filepath, mode="r", shape=tuple(memmap_configs["shape"]), dtype=memmap_configs["dtype"])

# %%
def format_distance_3bits(a, b):
    a = list(f"{a:03b}")
    b = list(f"{b:03b}")
    return 3*hamming(a, b)

# %%
result_dir = "../../../results"

# %% [markdown]
# ## Correlation analysis

# %% [markdown]
# ### Correlation with consistency (last layer)

# %%
os.makedirs(f"correlation_analysis_table", exist_ok=True)

dataset_names = ["CommonsenseQA", "QASC", "100TFQA", "GSM8K"]
model_names = ["Phi-3.5-mini-instruct", "Llama-3.1-8B-Instruct"]
prompting_strategies = ["zero-shot", "zero-shot-cot", "few-shot", "few-shot-cot"]

corr_matrix, p_matrix = np.zeros((len(model_names), len(dataset_names), len(prompting_strategies))), np.zeros((len(model_names), len(dataset_names), len(prompting_strategies)))
for i, model_name in enumerate(model_names):
    for j, dataset_name in enumerate(dataset_names):
        for k, prompting_strategy in enumerate(prompting_strategies):
            output_dir = f"{result_dir}/{dataset_name}/{model_name}"

            layer_wise_path = os.path.join(output_dir, f"{prompting_strategy}_layer_wise_hidden_states.dat")
            head_wise_path = os.path.join(output_dir, f"{prompting_strategy}_head_wise_hidden_states.dat")

            try:
                layer_wise_hidden_states = read_memmap(layer_wise_path)
            except Exception as e:
                # print(e)
                corr_matrix[i][j][k] = -2
                p_matrix[i][j][k] = -2
                continue
            num_samples, num_formats, num_layers, hidden_size = layer_wise_hidden_states.shape

            # Prepare pairwise consistency matrix (macro)
            score_path = os.path.join(output_dir, f"{prompting_strategy}_score.json")
            with open(score_path, "r") as fin:
                score = json.load(fin)
            pairwise_consistency_matrix = np.ones((num_formats, num_formats))
            for key, value in score["consistency"].items():
                if key == "mean":
                    continue
                split_key = key.split("_")
                ii, jj = int(split_key[0]), int(split_key[-1])
                pairwise_consistency_matrix[ii][jj] = value
                pairwise_consistency_matrix[jj][ii] = value

            for layer_idx in range(num_layers):
                if layer_idx != num_layers - 1:
                    continue

                # Step 1: Prepare input
                X = layer_wise_hidden_states[:,:,layer_idx,:]
                Y = np.tile(np.arange(num_formats), num_samples)
                X_mean = X.mean(axis=0)
                
                # Step 2: Macro analysis
                pairwise_distance_list, pairwise_consistency_list = [], []
                for ii in range(num_formats):
                    for jj in range(num_formats):
                        if ii < jj:
                            dist = euclidean(X_mean[ii], X_mean[jj])
                            pairwise_distance_list.append(dist)
                            pairwise_consistency_list.append(pairwise_consistency_matrix[ii][jj])

                pearson_corr, pearson_p = pearsonr(pairwise_distance_list, pairwise_consistency_list)
                spearman_corr, spearman_p = spearmanr(pairwise_distance_list, pairwise_consistency_list)

                # Print correlation results
                print(f"{dataset_name} / {model_name} / {prompting_strategy}")
                print(f"Layer {layer_idx}")
                print("Macro analysis")
                print(f"Pearson correlation: {pearson_corr:.2f} (p-value: {pearson_p:.3e})")
                print(f"Spearman correlation: {spearman_corr:.2f} (p-value: {spearman_p:.3e})")
                print()

                corr_matrix[i][j][k] = spearman_corr
                p_matrix[i][j][k] = spearman_p

prompting_strategies = ["Zero-shot", "Zero-shot CoT", "Few-shot", "Few-shot CoT"]
# Create LaTeX table string
latex_code = "\\begin{table}[ht]\n"
latex_code += "\\centering\n"
latex_code += "\\caption{Correlation analysis between last layer embedding distance and pairwise consistency. Each cell represents Spearman correlation coefficient and p-value (in parenthesis).}\n"
latex_code += "\\label{tab:last_layer_embedding_distance_correlation}\n"
latex_code += "\\begin{tabular}{c|c|cccc}\n"
latex_code += "\\toprule\n"
latex_code += "Model & Task & " + " & ".join(prompting_strategies) + " \\\\\n"
latex_code += "\\midrule\\midrule\n"

# Fill the table with data
for model_idx, model in enumerate(model_names):
    latex_code += f"\\multirow{{4}}{{*}}{{{model}}}\n"
    for task_idx, task in enumerate(dataset_names):
        latex_code += "      "
        latex_code += f"& {task} "
        for strat_idx in range(len(prompting_strategies)):
            corr = corr_matrix[model_idx, task_idx, strat_idx]
            p = p_matrix[model_idx, task_idx, strat_idx]

            # Skip conditions
            if corr < -1.5:
                latex_code += f"& - "
                continue

            corr_str = f"{corr:.2f}"
            p_str = f"{p:.3e}" if p < 0.001 else f"{p:.3f}"
            
            latex_code += f"& {corr_str} ({p_str}) "
        latex_code += "\\\\\n"
    latex_code += "\\midrule\n"

# Close LaTeX table
latex_code = latex_code.rstrip("\\midrule\n")  # Remove last midrule
latex_code += "\\\\\n"
latex_code += "\\bottomrule\n"
latex_code += "\\end{tabular}\n"
latex_code += "\\end{table}"

# Display the generated LaTeX table code
print(latex_code)

with open(f"correlation_analysis_table/last_layer_embedding_distance_correlation_with_consistency_table.txt", "w") as fout:
    fout.write(latex_code)
# Out:
# CommonsenseQA / Phi-3.5-mini-instruct / zero-shot
# Layer 31
# Macro analysis
# Pearson correlation: -0.60 (p-value: 7.451e-04)
# Spearman correlation: -0.60 (p-value: 8.310e-04)
#
# CommonsenseQA / Phi-3.5-mini-instruct / zero-shot-cot
# Layer 31
# Macro analysis
# Pearson correlation: -0.82 (p-value: 7.295e-08)
# Spearman correlation: -0.82 (p-value: 1.279e-07)
#
# CommonsenseQA / Phi-3.5-mini-instruct / few-shot
# Layer 31
# Macro analysis
# Pearson correlation: -0.12 (p-value: 5.558e-01)
# Spearman correlation: -0.06 (p-value: 7.668e-01)
#
# QASC / Phi-3.5-mini-instruct / zero-shot
# Layer 31
# Macro analysis
# Pearson correlation: -0.39 (p-value: 4.068e-02)
# Spearman correlation: -0.34 (p-value: 7.291e-02)
#
# QASC / Phi-3.5-mini-instruct / zero-shot-cot
# Layer 31
# Macro analysis
# Pearson correlation: -0.76 (p-value: 2.314e-06)
# Spearman correlation: -0.62 (p-value: 4.291e-04)
#
# QASC / Phi-3.5-mini-instruct / few-shot
# Layer 31
# Macro analysis
# Pearson correlation: -0.58 (p-value: 1.158e-03)
# Spearman correlation: -0.54 (p-value: 2.876e-03)
#
# QASC / Phi-3.5-mini-instruct / few-shot-cot
# Layer 31
# Macro analysis
# Pearson correlation: -0.41 (p-value: 3.247e-02)
# Spearman correlation: -0.31 (p-value: 1.096e-01)
#
# 100TFQA / Phi-3.5-mini-instruct / zero-shot
# Layer 31
# Macro analysis
# Pearson correlation: -0.38 (p-value: 4.917e-02)
# Spearman correlation: -0.41 (p-value: 2.934e-02)
#
# 100TFQA / Phi-3.5-mini-instruct / zero-shot-cot
# Layer 31
# Macro analysis
# Pearson correlation: -0.42 (p-value: 2.592e-02)
# Spearman correlation: -0.46 (p-value: 1.321e-02)
#
# 100TFQA / Phi-3.5-mini-instruct / few-shot
# Layer 31
# Macro analysis
# Pearson correlation: -0.13 (p-value: 5.256e-01)
# Spearman correlation: -0.01 (p-value: 9.434e-01)
#
# 100TFQA / Phi-3.5-mini-instruct / few-shot-cot
# Layer 31
# Macro analysis
# Pearson correlation: 0.22 (p-value: 2.534e-01)
# Spearman correlation: 0.13 (p-value: 4.966e-01)
#
# GSM8K / Phi-3.5-mini-instruct / zero-shot-cot
# Layer 31
# Macro analysis
# Pearson correlation: -0.50 (p-value: 6.623e-03)
# Spearman correlation: -0.42 (p-value: 2.426e-02)
#
# GSM8K / Phi-3.5-mini-instruct / few-shot-cot
# Layer 31
# Macro analysis
# Pearson correlation: -0.42 (p-value: 2.621e-02)
# Spearman correlation: -0.46 (p-value: 1.271e-02)
#
# CommonsenseQA / Llama-3.1-8B-Instruct / zero-shot
# Layer 31
# Macro analysis
# Pearson correlation: -0.23 (p-value: 2.409e-01)
# Spearman correlation: -0.32 (p-value: 9.630e-02)
#
# CommonsenseQA / Llama-3.1-8B-Instruct / zero-shot-cot
# Layer 31
# Macro analysis
# Pearson correlation: -0.35 (p-value: 6.897e-02)
# Spearman correlation: -0.36 (p-value: 5.680e-02)
#
# CommonsenseQA / Llama-3.1-8B-Instruct / few-shot
# Layer 31
# Macro analysis
# Pearson correlation: -0.22 (p-value: 2.536e-01)
# Spearman correlation: -0.20 (p-value: 3.047e-01)
#
# QASC / Llama-3.1-8B-Instruct / zero-shot
# Layer 31
# Macro analysis
# Pearson correlation: -0.04 (p-value: 8.248e-01)
# Spearman correlation: -0.12 (p-value: 5.392e-01)
#
# QASC / Llama-3.1-8B-Instruct / zero-shot-cot
# Layer 31
# Macro analysis
# Pearson correlation: -0.39 (p-value: 4.039e-02)
# Spearman correlation: -0.46 (p-value: 1.356e-02)
#
# QASC / Llama-3.1-8B-Instruct / few-shot
# Layer 31
# Macro analysis
# Pearson correlation: -0.35 (p-value: 6.527e-02)
# Spearman correlation: -0.21 (p-value: 2.768e-01)
#
# QASC / Llama-3.1-8B-Instruct / few-shot-cot
# Layer 31
# Macro analysis
# Pearson correlation: -0.33 (p-value: 8.680e-02)
# Spearman correlation: -0.33 (p-value: 8.236e-02)
#
# 100TFQA / Llama-3.1-8B-Instruct / zero-shot
# Layer 31
# Macro analysis
# Pearson correlation: -0.03 (p-value: 8.698e-01)
# Spearman correlation: 0.01 (p-value: 9.774e-01)
#
# 100TFQA / Llama-3.1-8B-Instruct / zero-shot-cot
# Layer 31
# Macro analysis
# Pearson correlation: -0.04 (p-value: 8.497e-01)
# Spearman correlation: -0.03 (p-value: 8.761e-01)
#
# 100TFQA / Llama-3.1-8B-Instruct / few-shot
# Layer 31
# Macro analysis
# Pearson correlation: -0.23 (p-value: 2.474e-01)
# Spearman correlation: -0.26 (p-value: 1.755e-01)
#
# 100TFQA / Llama-3.1-8B-Instruct / few-shot-cot
# Layer 31
# Macro analysis
# Pearson correlation: -0.37 (p-value: 5.287e-02)
# Spearman correlation: -0.33 (p-value: 8.771e-02)
#
# GSM8K / Llama-3.1-8B-Instruct / zero-shot-cot
# Layer 31
# Macro analysis
# Pearson correlation: 0.03 (p-value: 8.978e-01)
# Spearman correlation: -0.03 (p-value: 8.780e-01)
#
# GSM8K / Llama-3.1-8B-Instruct / few-shot-cot
# Layer 31
# Macro analysis
# Pearson correlation: -0.44 (p-value: 1.790e-02)
# Spearman correlation: -0.48 (p-value: 9.892e-03)
#
# \begin{table}[ht]
# \centering
# \caption{Correlation analysis between last layer embedding distance and pairwise consistency. Each cell represents Spearman correlation coefficient and p-value (in parenthesis).}
# \label{tab:last_layer_embedding_distance_correlation}
# \begin{tabular}{c|c|cccc}
# \toprule
# Model & Task & Zero-shot & Zero-shot CoT & Few-shot & Few-shot CoT \\
# \midrule\midrule
# \multirow{4}{*}{Phi-3.5-mini-instruct}
#       & CommonsenseQA & -0.60 (8.310e-04) & -0.82 (1.279e-07) & -0.06 (0.767) & - \\
#       & QASC & -0.34 (0.073) & -0.62 (4.291e-04) & -0.54 (0.003) & -0.31 (0.110) \\
#       & 100TFQA & -0.41 (0.029) & -0.46 (0.013) & -0.01 (0.943) & 0.13 (0.497) \\
#       & GSM8K & - & -0.42 (0.024) & - & -0.46 (0.013) \\
# \midrule
# \multirow{4}{*}{Llama-3.1-8B-Instruct}
#       & CommonsenseQA & -0.32 (0.096) & -0.36 (0.057) & -0.20 (0.305) & - \\
#       & QASC & -0.12 (0.539) & -0.46 (0.014) & -0.21 (0.277) & -0.33 (0.082) \\
#       & 100TFQA & 0.01 (0.977) & -0.03 (0.876) & -0.26 (0.175) & -0.33 (0.088) \\
#       & GSM8K & - & -0.03 (0.878) & - & -0.48 (0.010) \\
# \bottomrule
# \end{tabular}
# \end{table}

# %% [markdown]
# ### Correlation with consistency (best layer)

# %%
os.makedirs(f"correlation_analysis_table", exist_ok=True)

dataset_names = ["CommonsenseQA", "QASC", "100TFQA", "GSM8K"]
model_names = ["Phi-3.5-mini-instruct", "Llama-3.1-8B-Instruct"]
prompting_strategies = ["zero-shot", "zero-shot-cot", "few-shot", "few-shot-cot"]

NUM_LAYERS = 32
corr_matrix, p_matrix = np.zeros((len(model_names), len(dataset_names), len(prompting_strategies), NUM_LAYERS)), np.zeros((len(model_names), len(dataset_names), len(prompting_strategies), NUM_LAYERS))
for i, model_name in enumerate(model_names):
    for j, dataset_name in enumerate(dataset_names):
        for k, prompting_strategy in enumerate(prompting_strategies):
            output_dir = f"{result_dir}/{dataset_name}/{model_name}"

            layer_wise_path = os.path.join(output_dir, f"{prompting_strategy}_layer_wise_hidden_states.dat")
            head_wise_path = os.path.join(output_dir, f"{prompting_strategy}_head_wise_hidden_states.dat")

            try:
                layer_wise_hidden_states = read_memmap(layer_wise_path)
            except Exception as e:
                print(e)
                # corr_matrix[i][j][k] = -2
                # p_matrix[i][j][k] = -2
                continue
            num_samples, num_formats, num_layers, hidden_size = layer_wise_hidden_states.shape

            # Prepare pairwise consistency matrix (macro)
            score_path = os.path.join(output_dir, f"{prompting_strategy}_score.json")
            with open(score_path, "r") as fin:
                score = json.load(fin)
            pairwise_consistency_matrix = np.ones((num_formats, num_formats))
            for key, value in score["consistency"].items():
                if key == "mean":
                    continue
                split_key = key.split("_")
                ii, jj = int(split_key[0]), int(split_key[-1])
                pairwise_consistency_matrix[ii][jj] = value
                pairwise_consistency_matrix[jj][ii] = value

            for layer_idx in range(num_layers):
                # Step 1: Prepare input
                X = layer_wise_hidden_states[:,:,layer_idx,:]
                Y = np.tile(np.arange(num_formats), num_samples)
                X_mean = X.mean(axis=0)
                
                # Step 2: Macro analysis
                pairwise_distance_list, pairwise_consistency_list = [], []
                for ii in range(num_formats):
                    for jj in range(num_formats):
                        if ii < jj:
                            dist = euclidean(X_mean[ii], X_mean[jj])
                            pairwise_distance_list.append(dist)
                            pairwise_consistency_list.append(pairwise_consistency_matrix[ii][jj])

                pearson_corr, pearson_p = pearsonr(pairwise_distance_list, pairwise_consistency_list)
                spearman_corr, spearman_p = spearmanr(pairwise_distance_list, pairwise_consistency_list)

                # Print correlation results
                print(f"{dataset_name} / {model_name} / {prompting_strategy}")
                print(f"Layer {layer_idx}")
                print("Macro analysis")
                print(f"Pearson correlation: {pearson_corr:.2f} (p-value: {pearson_p:.3e})")
                print(f"Spearman correlation: {spearman_corr:.2f} (p-value: {spearman_p:.3e})")
                print()

                # if spearman_corr < corr_matrix[i][j][k]:
                corr_matrix[i][j][k][layer_idx] = spearman_corr
                p_matrix[i][j][k][layer_idx] = spearman_p

# prompting_strategies = ["Zero-shot", "Zero-shot CoT", "Few-shot", "Few-shot CoT"]
# # Create LaTeX table string
# latex_code = "\\begin{table}[ht]\n"
# latex_code += "\\centering\n"
# latex_code += "\\caption{Correlation analysis between best layer embedding distance and pairwise consistency. A layer in which the correlation is maximized is selected as the best layer. Each cell represents Spearman correlation coefficient and p-value (in parenthesis).}\n"
# latex_code += "\\label{tab:best_layer_embedding_distance_correlation}\n"
# latex_code += "\\begin{tabular}{c|c|cccc}\n"
# latex_code += "\\toprule\n"
# latex_code += "Model & Task & " + " & ".join(prompting_strategies) + " \\\\\n"
# latex_code += "\\midrule\\midrule\n"

# # Fill the table with data
# for model_idx, model in enumerate(model_names):
#     latex_code += f"\\multirow{{4}}{{*}}{{{model}}}\n"
#     for task_idx, task in enumerate(dataset_names):
#         latex_code += "      "
#         latex_code += f"& {task} "
#         for strat_idx in range(len(prompting_strategies)):
#             corr = corr_matrix[model_idx, task_idx, strat_idx]
#             p = p_matrix[model_idx, task_idx, strat_idx]

#             # Skip conditions
#             if corr < -1.5:
#                 latex_code += f"& - "
#                 continue

#             corr_str = f"{corr:.2f}"
#             p_str = f"{p:.3e}" if p < 0.001 else f"{p:.3f}"
            
#             latex_code += f"& {corr_str} ({p_str}) "
#         latex_code += "\\\\\n"
#     latex_code += "\\midrule\n"

# # Close LaTeX table
# latex_code = latex_code.rstrip("\\midrule\n")  # Remove last midrule
# latex_code += "\\\\\n"
# latex_code += "\\bottomrule\n"
# latex_code += "\\end{tabular}\n"
# latex_code += "\\end{table}"

# # Display the generated LaTeX table code
# print(latex_code)

# with open(f"correlation_analysis_table/best_layer_embedding_distance_correlation_with_consistency_table.txt", "w") as fout:
#     fout.write(latex_code)
# Out:
# CommonsenseQA / Phi-3.5-mini-instruct / zero-shot
# Layer 0
# Macro analysis
# Pearson correlation: -0.37 (p-value: 4.973e-02)
# Spearman correlation: -0.44 (p-value: 1.794e-02)
#
# CommonsenseQA / Phi-3.5-mini-instruct / zero-shot
# Layer 1
# Macro analysis
# Pearson correlation: -0.38 (p-value: 4.808e-02)
# Spearman correlation: -0.39 (p-value: 3.992e-02)
#
# CommonsenseQA / Phi-3.5-mini-instruct / zero-shot
# Layer 2
# Macro analysis
# Pearson correlation: -0.12 (p-value: 5.297e-01)
# Spearman correlation: -0.15 (p-value: 4.436e-01)
#
# CommonsenseQA / Phi-3.5-mini-instruct / zero-shot
# Layer 3
# Macro analysis
# Pearson correlation: -0.19 (p-value: 3.219e-01)
# Spearman correlation: -0.19 (p-value: 3.377e-01)
#
# CommonsenseQA / Phi-3.5-mini-instruct / zero-shot
# Layer 4
# Macro analysis
# Pearson correlation: -0.24 (p-value: 2.214e-01)
# Spearman correlation: -0.29 (p-value: 1.342e-01)
#
# CommonsenseQA / Phi-3.5-mini-instruct / zero-shot
# Layer 5
# Macro analysis
# Pearson correlation: -0.27 (p-value: 1.617e-01)
# Spearman correlation: -0.36 (p-value: 6.236e-02)
#
# CommonsenseQA / Phi-3.5-mini-instruct / zero-shot
# Layer 6
# Macro analysis
# Pearson correlation: -0.30 (p-value: 1.263e-01)
# Spearman correlation: -0.43 (p-value: 2.115e-02)
#
# CommonsenseQA / Phi-3.5-mini-instruct / zero-shot
# Layer 7
# Macro analysis
# Pearson correlation: -0.30 (p-value: 1.198e-01)
# Spearman correlation: -0.46 (p-value: 1.379e-02)
#
# CommonsenseQA / Phi-3.5-mini-instruct / zero-shot
# Layer 8
# Macro analysis
# Pearson correlation: -0.32 (p-value: 9.788e-02)
# Spearman correlation: -0.44 (p-value: 2.019e-02)
#
# CommonsenseQA / Phi-3.5-mini-instruct / zero-shot
# Layer 9
# Macro analysis
# Pearson correlation: -0.34 (p-value: 8.010e-02)
# Spearman correlation: -0.43 (p-value: 2.083e-02)
#
# CommonsenseQA / Phi-3.5-mini-instruct / zero-shot
# Layer 10
# Macro analysis
# Pearson correlation: -0.32 (p-value: 9.476e-02)
# Spearman correlation: -0.44 (p-value: 1.942e-02)
#
# CommonsenseQA / Phi-3.5-mini-instruct / zero-shot
# Layer 11
# Macro analysis
# Pearson correlation: -0.45 (p-value: 1.545e-02)
# Spearman correlation: -0.56 (p-value: 2.132e-03)
#
# CommonsenseQA / Phi-3.5-mini-instruct / zero-shot
# Layer 12
# Macro analysis
# Pearson correlation: -0.49 (p-value: 7.882e-03)
# Spearman correlation: -0.54 (p-value: 2.730e-03)
#
# CommonsenseQA / Phi-3.5-mini-instruct / zero-shot
# Layer 13
# Macro analysis
# Pearson correlation: -0.47 (p-value: 1.126e-02)
# Spearman correlation: -0.53 (p-value: 3.826e-03)
#
# CommonsenseQA / Phi-3.5-mini-instruct / zero-shot
# Layer 14
# Macro analysis
# Pearson correlation: -0.52 (p-value: 4.659e-03)
# Spearman correlation: -0.56 (p-value: 1.939e-03)
#
# CommonsenseQA / Phi-3.5-mini-instruct / zero-shot
# Layer 15
# Macro analysis
# Pearson correlation: -0.53 (p-value: 3.452e-03)
# Spearman correlation: -0.62 (p-value: 4.196e-04)
#
# CommonsenseQA / Phi-3.5-mini-instruct / zero-shot
# Layer 16
# Macro analysis
# Pearson correlation: -0.55 (p-value: 2.321e-03)
# Spearman correlation: -0.65 (p-value: 1.894e-04)
#
# CommonsenseQA / Phi-3.5-mini-instruct / zero-shot
# Layer 17
# Macro analysis
# Pearson correlation: -0.55 (p-value: 2.264e-03)
# Spearman correlation: -0.64 (p-value: 2.327e-04)
#
# CommonsenseQA / Phi-3.5-mini-instruct / zero-shot
# Layer 18
# Macro analysis
# Pearson correlation: -0.56 (p-value: 1.794e-03)
# Spearman correlation: -0.62 (p-value: 4.618e-04)
#
# CommonsenseQA / Phi-3.5-mini-instruct / zero-shot
# Layer 19
# Macro analysis
# Pearson correlation: -0.63 (p-value: 2.984e-04)
# Spearman correlation: -0.72 (p-value: 1.717e-05)
#
# CommonsenseQA / Phi-3.5-mini-instruct / zero-shot
# Layer 20
# Macro analysis
# Pearson correlation: -0.65 (p-value: 1.564e-04)
# Spearman correlation: -0.69 (p-value: 4.777e-05)
#
# CommonsenseQA / Phi-3.5-mini-instruct / zero-shot
# Layer 21
# Macro analysis
# Pearson correlation: -0.65 (p-value: 1.750e-04)
# Spearman correlation: -0.66 (p-value: 1.324e-04)
#
# CommonsenseQA / Phi-3.5-mini-instruct / zero-shot
# Layer 22
# Macro analysis
# Pearson correlation: -0.63 (p-value: 3.542e-04)
# Spearman correlation: -0.64 (p-value: 2.417e-04)
#
# CommonsenseQA / Phi-3.5-mini-instruct / zero-shot
# Layer 23
# Macro analysis
# Pearson correlation: -0.63 (p-value: 3.597e-04)
# Spearman correlation: -0.63 (p-value: 3.573e-04)
#
# CommonsenseQA / Phi-3.5-mini-instruct / zero-shot
# Layer 24
# Macro analysis
# Pearson correlation: -0.63 (p-value: 2.933e-04)
# Spearman correlation: -0.65 (p-value: 1.641e-04)
#
# CommonsenseQA / Phi-3.5-mini-instruct / zero-shot
# Layer 25
# Macro analysis
# Pearson correlation: -0.64 (p-value: 2.314e-04)
# Spearman correlation: -0.68 (p-value: 7.922e-05)
#
# CommonsenseQA / Phi-3.5-mini-instruct / zero-shot
# Layer 26
# Macro analysis
# Pearson correlation: -0.64 (p-value: 2.341e-04)
# Spearman correlation: -0.64 (p-value: 2.331e-04)
#
# CommonsenseQA / Phi-3.5-mini-instruct / zero-shot
# Layer 27
# Macro analysis
# Pearson correlation: -0.62 (p-value: 3.864e-04)
# Spearman correlation: -0.61 (p-value: 5.653e-04)
#
# CommonsenseQA / Phi-3.5-mini-instruct / zero-shot
# Layer 28
# Macro analysis
# Pearson correlation: -0.62 (p-value: 4.247e-04)
# Spearman correlation: -0.61 (p-value: 5.611e-04)
#
# CommonsenseQA / Phi-3.5-mini-instruct / zero-shot
# Layer 29
# Macro analysis
# Pearson correlation: -0.61 (p-value: 5.749e-04)
# Spearman correlation: -0.61 (p-value: 5.949e-04)
#
# CommonsenseQA / Phi-3.5-mini-instruct / zero-shot
# Layer 30
# Macro analysis
# Pearson correlation: -0.62 (p-value: 4.424e-04)
# Spearman correlation: -0.62 (p-value: 4.628e-04)
#
# CommonsenseQA / Phi-3.5-mini-instruct / zero-shot
# Layer 31
# Macro analysis
# Pearson correlation: -0.60 (p-value: 7.451e-04)
# Spearman correlation: -0.60 (p-value: 8.310e-04)
#
# CommonsenseQA / Phi-3.5-mini-instruct / zero-shot-cot
# Layer 0
# Macro analysis
# Pearson correlation: -0.64 (p-value: 2.431e-04)
# Spearman correlation: -0.68 (p-value: 7.709e-05)
#
# CommonsenseQA / Phi-3.5-mini-instruct / zero-shot-cot
# Layer 1
# Macro analysis
# Pearson correlation: -0.58 (p-value: 1.358e-03)
# Spearman correlation: -0.62 (p-value: 4.761e-04)
#
# CommonsenseQA / Phi-3.5-mini-instruct / zero-shot-cot
# Layer 2
# Macro analysis
# Pearson correlation: -0.57 (p-value: 1.684e-03)
# Spearman correlation: -0.41 (p-value: 2.955e-02)
#
# CommonsenseQA / Phi-3.5-mini-instruct / zero-shot-cot
# Layer 3
# Macro analysis
# Pearson correlation: -0.65 (p-value: 1.572e-04)
# Spearman correlation: -0.44 (p-value: 1.919e-02)
#
# CommonsenseQA / Phi-3.5-mini-instruct / zero-shot-cot
# Layer 4
# Macro analysis
# Pearson correlation: -0.73 (p-value: 1.194e-05)
# Spearman correlation: -0.63 (p-value: 3.491e-04)
#
# CommonsenseQA / Phi-3.5-mini-instruct / zero-shot-cot
# Layer 5
# Macro analysis
# Pearson correlation: -0.77 (p-value: 1.372e-06)
# Spearman correlation: -0.67 (p-value: 1.034e-04)
#
# CommonsenseQA / Phi-3.5-mini-instruct / zero-shot-cot
# Layer 6
# Macro analysis
# Pearson correlation: -0.82 (p-value: 7.429e-08)
# Spearman correlation: -0.82 (p-value: 1.052e-07)
#
# CommonsenseQA / Phi-3.5-mini-instruct / zero-shot-cot
# Layer 7
# Macro analysis
# Pearson correlation: -0.83 (p-value: 5.173e-08)
# Spearman correlation: -0.83 (p-value: 3.978e-08)
#
# CommonsenseQA / Phi-3.5-mini-instruct / zero-shot-cot
# Layer 8
# Macro analysis
# Pearson correlation: -0.82 (p-value: 6.949e-08)
# Spearman correlation: -0.85 (p-value: 8.408e-09)
#
# CommonsenseQA / Phi-3.5-mini-instruct / zero-shot-cot
# Layer 9
# Macro analysis
# Pearson correlation: -0.83 (p-value: 5.165e-08)
# Spearman correlation: -0.86 (p-value: 4.385e-09)
#
# CommonsenseQA / Phi-3.5-mini-instruct / zero-shot-cot
# Layer 10
# Macro analysis
# Pearson correlation: -0.84 (p-value: 2.528e-08)
# Spearman correlation: -0.88 (p-value: 1.089e-09)
#
# CommonsenseQA / Phi-3.5-mini-instruct / zero-shot-cot
# Layer 11
# Macro analysis
# Pearson correlation: -0.81 (p-value: 1.629e-07)
# Spearman correlation: -0.80 (p-value: 2.658e-07)
#
# CommonsenseQA / Phi-3.5-mini-instruct / zero-shot-cot
# Layer 12
# Macro analysis
# Pearson correlation: -0.72 (p-value: 1.434e-05)
# Spearman correlation: -0.68 (p-value: 7.464e-05)
#
# CommonsenseQA / Phi-3.5-mini-instruct / zero-shot-cot
# Layer 13
# Macro analysis
# Pearson correlation: -0.67 (p-value: 8.737e-05)
# Spearman correlation: -0.68 (p-value: 6.478e-05)
#
# CommonsenseQA / Phi-3.5-mini-instruct / zero-shot-cot
# Layer 14
# Macro analysis
# Pearson correlation: -0.69 (p-value: 4.196e-05)
# Spearman correlation: -0.70 (p-value: 4.033e-05)
#
# CommonsenseQA / Phi-3.5-mini-instruct / zero-shot-cot
# Layer 15
# Macro analysis
# Pearson correlation: -0.65 (p-value: 1.750e-04)
# Spearman correlation: -0.67 (p-value: 1.036e-04)
#
# CommonsenseQA / Phi-3.5-mini-instruct / zero-shot-cot
# Layer 16
# Macro analysis
# Pearson correlation: -0.52 (p-value: 4.455e-03)
# Spearman correlation: -0.50 (p-value: 7.117e-03)
#
# CommonsenseQA / Phi-3.5-mini-instruct / zero-shot-cot
# Layer 17
# Macro analysis
# Pearson correlation: -0.54 (p-value: 3.192e-03)
# Spearman correlation: -0.51 (p-value: 5.166e-03)
#
# CommonsenseQA / Phi-3.5-mini-instruct / zero-shot-cot
# Layer 18
# Macro analysis
# Pearson correlation: -0.65 (p-value: 1.653e-04)
# Spearman correlation: -0.67 (p-value: 1.062e-04)
#
# CommonsenseQA / Phi-3.5-mini-instruct / zero-shot-cot
# Layer 19
# Macro analysis
# Pearson correlation: -0.73 (p-value: 8.660e-06)
# Spearman correlation: -0.72 (p-value: 1.684e-05)
#
# CommonsenseQA / Phi-3.5-mini-instruct / zero-shot-cot
# Layer 20
# Macro analysis
# Pearson correlation: -0.72 (p-value: 1.835e-05)
# Spearman correlation: -0.70 (p-value: 3.799e-05)
#
# CommonsenseQA / Phi-3.5-mini-instruct / zero-shot-cot
# Layer 21
# Macro analysis
# Pearson correlation: -0.82 (p-value: 1.074e-07)
# Spearman correlation: -0.73 (p-value: 8.874e-06)
#
# CommonsenseQA / Phi-3.5-mini-instruct / zero-shot-cot
# Layer 22
# Macro analysis
# Pearson correlation: -0.83 (p-value: 4.868e-08)
# Spearman correlation: -0.78 (p-value: 1.224e-06)
#
# CommonsenseQA / Phi-3.5-mini-instruct / zero-shot-cot
# Layer 23
# Macro analysis
# Pearson correlation: -0.79 (p-value: 4.988e-07)
# Spearman correlation: -0.71 (p-value: 2.473e-05)
#
# CommonsenseQA / Phi-3.5-mini-instruct / zero-shot-cot
# Layer 24
# Macro analysis
# Pearson correlation: -0.80 (p-value: 3.161e-07)
# Spearman correlation: -0.71 (p-value: 2.688e-05)
#
# CommonsenseQA / Phi-3.5-mini-instruct / zero-shot-cot
# Layer 25
# Macro analysis
# Pearson correlation: -0.82 (p-value: 1.171e-07)
# Spearman correlation: -0.73 (p-value: 8.456e-06)
#
# CommonsenseQA / Phi-3.5-mini-instruct / zero-shot-cot
# Layer 26
# Macro analysis
# Pearson correlation: -0.82 (p-value: 9.816e-08)
# Spearman correlation: -0.73 (p-value: 1.078e-05)
#
# CommonsenseQA / Phi-3.5-mini-instruct / zero-shot-cot
# Layer 27
# Macro analysis
# Pearson correlation: -0.83 (p-value: 6.270e-08)
# Spearman correlation: -0.76 (p-value: 2.131e-06)
#
# CommonsenseQA / Phi-3.5-mini-instruct / zero-shot-cot
# Layer 28
# Macro analysis
# Pearson correlation: -0.83 (p-value: 4.521e-08)
# Spearman correlation: -0.78 (p-value: 8.403e-07)
#
# CommonsenseQA / Phi-3.5-mini-instruct / zero-shot-cot
# Layer 29
# Macro analysis
# Pearson correlation: -0.83 (p-value: 5.921e-08)
# Spearman correlation: -0.76 (p-value: 3.243e-06)
#
# CommonsenseQA / Phi-3.5-mini-instruct / zero-shot-cot
# Layer 30
# Macro analysis
# Pearson correlation: -0.83 (p-value: 6.636e-08)
# Spearman correlation: -0.77 (p-value: 1.962e-06)
#
# CommonsenseQA / Phi-3.5-mini-instruct / zero-shot-cot
# Layer 31
# Macro analysis
# Pearson correlation: -0.82 (p-value: 7.295e-08)
# Spearman correlation: -0.82 (p-value: 1.279e-07)
#
# CommonsenseQA / Phi-3.5-mini-instruct / few-shot
# Layer 0
# Macro analysis
# Pearson correlation: -0.45 (p-value: 1.765e-02)
# Spearman correlation: -0.44 (p-value: 1.802e-02)
#
# CommonsenseQA / Phi-3.5-mini-instruct / few-shot
# Layer 1
# Macro analysis
# Pearson correlation: -0.49 (p-value: 8.748e-03)
# Spearman correlation: -0.57 (p-value: 1.698e-03)
#
# CommonsenseQA / Phi-3.5-mini-instruct / few-shot
# Layer 2
# Macro analysis
# Pearson correlation: -0.37 (p-value: 5.257e-02)
# Spearman correlation: -0.38 (p-value: 4.592e-02)
#
# CommonsenseQA / Phi-3.5-mini-instruct / few-shot
# Layer 3
# Macro analysis
# Pearson correlation: -0.45 (p-value: 1.656e-02)
# Spearman correlation: -0.53 (p-value: 3.606e-03)
#
# CommonsenseQA / Phi-3.5-mini-instruct / few-shot
# Layer 4
# Macro analysis
# Pearson correlation: -0.43 (p-value: 2.162e-02)
# Spearman correlation: -0.52 (p-value: 4.407e-03)
#
# CommonsenseQA / Phi-3.5-mini-instruct / few-shot
# Layer 5
# Macro analysis
# Pearson correlation: -0.40 (p-value: 3.437e-02)
# Spearman correlation: -0.46 (p-value: 1.292e-02)
#
# CommonsenseQA / Phi-3.5-mini-instruct / few-shot
# Layer 6
# Macro analysis
# Pearson correlation: -0.38 (p-value: 4.808e-02)
# Spearman correlation: -0.41 (p-value: 2.887e-02)
#
# CommonsenseQA / Phi-3.5-mini-instruct / few-shot
# Layer 7
# Macro analysis
# Pearson correlation: -0.41 (p-value: 3.100e-02)
# Spearman correlation: -0.49 (p-value: 7.587e-03)
#
# CommonsenseQA / Phi-3.5-mini-instruct / few-shot
# Layer 8
# Macro analysis
# Pearson correlation: -0.45 (p-value: 1.744e-02)
# Spearman correlation: -0.54 (p-value: 2.751e-03)
#
# CommonsenseQA / Phi-3.5-mini-instruct / few-shot
# Layer 9
# Macro analysis
# Pearson correlation: -0.46 (p-value: 1.270e-02)
# Spearman correlation: -0.56 (p-value: 1.878e-03)
#
# CommonsenseQA / Phi-3.5-mini-instruct / few-shot
# Layer 10
# Macro analysis
# Pearson correlation: -0.45 (p-value: 1.757e-02)
# Spearman correlation: -0.50 (p-value: 7.283e-03)
#
# CommonsenseQA / Phi-3.5-mini-instruct / few-shot
# Layer 11
# Macro analysis
# Pearson correlation: -0.44 (p-value: 1.774e-02)
# Spearman correlation: -0.48 (p-value: 9.058e-03)
#
# CommonsenseQA / Phi-3.5-mini-instruct / few-shot
# Layer 12
# Macro analysis
# Pearson correlation: -0.46 (p-value: 1.388e-02)
# Spearman correlation: -0.49 (p-value: 8.186e-03)
#
# CommonsenseQA / Phi-3.5-mini-instruct / few-shot
# Layer 13
# Macro analysis
# Pearson correlation: -0.41 (p-value: 2.973e-02)
# Spearman correlation: -0.40 (p-value: 3.413e-02)
#
# CommonsenseQA / Phi-3.5-mini-instruct / few-shot
# Layer 14
# Macro analysis
# Pearson correlation: -0.42 (p-value: 2.504e-02)
# Spearman correlation: -0.39 (p-value: 4.124e-02)
#
# CommonsenseQA / Phi-3.5-mini-instruct / few-shot
# Layer 15
# Macro analysis
# Pearson correlation: -0.42 (p-value: 2.770e-02)
# Spearman correlation: -0.42 (p-value: 2.710e-02)
#
# CommonsenseQA / Phi-3.5-mini-instruct / few-shot
# Layer 16
# Macro analysis
# Pearson correlation: -0.39 (p-value: 4.164e-02)
# Spearman correlation: -0.39 (p-value: 4.144e-02)
#
# CommonsenseQA / Phi-3.5-mini-instruct / few-shot
# Layer 17
# Macro analysis
# Pearson correlation: -0.40 (p-value: 3.551e-02)
# Spearman correlation: -0.40 (p-value: 3.297e-02)
#
# CommonsenseQA / Phi-3.5-mini-instruct / few-shot
# Layer 18
# Macro analysis
# Pearson correlation: -0.33 (p-value: 8.599e-02)
# Spearman correlation: -0.35 (p-value: 6.533e-02)
#
# CommonsenseQA / Phi-3.5-mini-instruct / few-shot
# Layer 19
# Macro analysis
# Pearson correlation: -0.26 (p-value: 1.751e-01)
# Spearman correlation: -0.25 (p-value: 1.909e-01)
#
# CommonsenseQA / Phi-3.5-mini-instruct / few-shot
# Layer 20
# Macro analysis
# Pearson correlation: -0.17 (p-value: 3.851e-01)
# Spearman correlation: -0.16 (p-value: 4.305e-01)
#
# CommonsenseQA / Phi-3.5-mini-instruct / few-shot
# Layer 21
# Macro analysis
# Pearson correlation: -0.15 (p-value: 4.456e-01)
# Spearman correlation: -0.12 (p-value: 5.428e-01)
#
# CommonsenseQA / Phi-3.5-mini-instruct / few-shot
# Layer 22
# Macro analysis
# Pearson correlation: -0.16 (p-value: 4.230e-01)
# Spearman correlation: -0.11 (p-value: 5.814e-01)
#
# CommonsenseQA / Phi-3.5-mini-instruct / few-shot
# Layer 23
# Macro analysis
# Pearson correlation: -0.17 (p-value: 3.893e-01)
# Spearman correlation: -0.13 (p-value: 4.982e-01)
#
# CommonsenseQA / Phi-3.5-mini-instruct / few-shot
# Layer 24
# Macro analysis
# Pearson correlation: -0.14 (p-value: 4.656e-01)
# Spearman correlation: -0.12 (p-value: 5.317e-01)
#
# CommonsenseQA / Phi-3.5-mini-instruct / few-shot
# Layer 25
# Macro analysis
# Pearson correlation: -0.12 (p-value: 5.540e-01)
# Spearman correlation: -0.08 (p-value: 6.897e-01)
#
# CommonsenseQA / Phi-3.5-mini-instruct / few-shot
# Layer 26
# Macro analysis
# Pearson correlation: -0.11 (p-value: 5.900e-01)
# Spearman correlation: -0.08 (p-value: 6.922e-01)
#
# CommonsenseQA / Phi-3.5-mini-instruct / few-shot
# Layer 27
# Macro analysis
# Pearson correlation: -0.11 (p-value: 5.707e-01)
# Spearman correlation: -0.08 (p-value: 6.897e-01)
#
# CommonsenseQA / Phi-3.5-mini-instruct / few-shot
# Layer 28
# Macro analysis
# Pearson correlation: -0.12 (p-value: 5.523e-01)
# Spearman correlation: -0.09 (p-value: 6.461e-01)
#
# CommonsenseQA / Phi-3.5-mini-instruct / few-shot
# Layer 29
# Macro analysis
# Pearson correlation: -0.13 (p-value: 5.151e-01)
# Spearman correlation: -0.12 (p-value: 5.419e-01)
#
# CommonsenseQA / Phi-3.5-mini-instruct / few-shot
# Layer 30
# Macro analysis
# Pearson correlation: -0.13 (p-value: 5.183e-01)
# Spearman correlation: -0.10 (p-value: 5.988e-01)
#
# CommonsenseQA / Phi-3.5-mini-instruct / few-shot
# Layer 31
# Macro analysis
# Pearson correlation: -0.12 (p-value: 5.558e-01)
# Spearman correlation: -0.06 (p-value: 7.668e-01)
#
# [Errno 2] No such file or directory: '../../../results/CommonsenseQA/Phi-3.5-mini-instruct/few-shot-cot_layer_wise_hidden_states.conf'
# QASC / Phi-3.5-mini-instruct / zero-shot
# Layer 0
# Macro analysis
# Pearson correlation: -0.37 (p-value: 4.961e-02)
# Spearman correlation: -0.48 (p-value: 1.014e-02)
#
# QASC / Phi-3.5-mini-instruct / zero-shot
# Layer 1
# Macro analysis
# Pearson correlation: -0.37 (p-value: 4.974e-02)
# Spearman correlation: -0.40 (p-value: 3.692e-02)
#
# QASC / Phi-3.5-mini-instruct / zero-shot
# Layer 2
# Macro analysis
# Pearson correlation: 0.04 (p-value: 8.369e-01)
# Spearman correlation: 0.03 (p-value: 8.931e-01)
#
# QASC / Phi-3.5-mini-instruct / zero-shot
# Layer 3
# Macro analysis
# Pearson correlation: -0.06 (p-value: 7.625e-01)
# Spearman correlation: 0.01 (p-value: 9.508e-01)
#
# QASC / Phi-3.5-mini-instruct / zero-shot
# Layer 4
# Macro analysis
# Pearson correlation: -0.11 (p-value: 5.883e-01)
# Spearman correlation: -0.12 (p-value: 5.334e-01)
#
# QASC / Phi-3.5-mini-instruct / zero-shot
# Layer 5
# Macro analysis
# Pearson correlation: -0.14 (p-value: 4.691e-01)
# Spearman correlation: -0.22 (p-value: 2.596e-01)
#
# QASC / Phi-3.5-mini-instruct / zero-shot
# Layer 6
# Macro analysis
# Pearson correlation: -0.22 (p-value: 2.639e-01)
# Spearman correlation: -0.36 (p-value: 5.940e-02)
#
# QASC / Phi-3.5-mini-instruct / zero-shot
# Layer 7
# Macro analysis
# Pearson correlation: -0.22 (p-value: 2.515e-01)
# Spearman correlation: -0.36 (p-value: 5.796e-02)
#
# QASC / Phi-3.5-mini-instruct / zero-shot
# Layer 8
# Macro analysis
# Pearson correlation: -0.23 (p-value: 2.373e-01)
# Spearman correlation: -0.39 (p-value: 4.289e-02)
#
# QASC / Phi-3.5-mini-instruct / zero-shot
# Layer 9
# Macro analysis
# Pearson correlation: -0.23 (p-value: 2.301e-01)
# Spearman correlation: -0.40 (p-value: 3.530e-02)
#
# QASC / Phi-3.5-mini-instruct / zero-shot
# Layer 10
# Macro analysis
# Pearson correlation: -0.22 (p-value: 2.543e-01)
# Spearman correlation: -0.40 (p-value: 3.585e-02)
#
# QASC / Phi-3.5-mini-instruct / zero-shot
# Layer 11
# Macro analysis
# Pearson correlation: -0.30 (p-value: 1.184e-01)
# Spearman correlation: -0.39 (p-value: 3.755e-02)
#
# QASC / Phi-3.5-mini-instruct / zero-shot
# Layer 12
# Macro analysis
# Pearson correlation: -0.27 (p-value: 1.575e-01)
# Spearman correlation: -0.28 (p-value: 1.473e-01)
#
# QASC / Phi-3.5-mini-instruct / zero-shot
# Layer 13
# Macro analysis
# Pearson correlation: -0.26 (p-value: 1.751e-01)
# Spearman correlation: -0.32 (p-value: 1.003e-01)
#
# QASC / Phi-3.5-mini-instruct / zero-shot
# Layer 14
# Macro analysis
# Pearson correlation: -0.32 (p-value: 1.008e-01)
# Spearman correlation: -0.35 (p-value: 7.195e-02)
#
# QASC / Phi-3.5-mini-instruct / zero-shot
# Layer 15
# Macro analysis
# Pearson correlation: -0.33 (p-value: 8.836e-02)
# Spearman correlation: -0.35 (p-value: 6.910e-02)
#
# QASC / Phi-3.5-mini-instruct / zero-shot
# Layer 16
# Macro analysis
# Pearson correlation: -0.33 (p-value: 8.939e-02)
# Spearman correlation: -0.42 (p-value: 2.643e-02)
#
# QASC / Phi-3.5-mini-instruct / zero-shot
# Layer 17
# Macro analysis
# Pearson correlation: -0.34 (p-value: 7.966e-02)
# Spearman correlation: -0.45 (p-value: 1.575e-02)
#
# QASC / Phi-3.5-mini-instruct / zero-shot
# Layer 18
# Macro analysis
# Pearson correlation: -0.36 (p-value: 5.997e-02)
# Spearman correlation: -0.39 (p-value: 3.781e-02)
#
# QASC / Phi-3.5-mini-instruct / zero-shot
# Layer 19
# Macro analysis
# Pearson correlation: -0.47 (p-value: 1.097e-02)
# Spearman correlation: -0.52 (p-value: 4.157e-03)
#
# QASC / Phi-3.5-mini-instruct / zero-shot
# Layer 20
# Macro analysis
# Pearson correlation: -0.49 (p-value: 8.790e-03)
# Spearman correlation: -0.50 (p-value: 6.348e-03)
#
# QASC / Phi-3.5-mini-instruct / zero-shot
# Layer 21
# Macro analysis
# Pearson correlation: -0.47 (p-value: 1.218e-02)
# Spearman correlation: -0.48 (p-value: 9.297e-03)
#
# QASC / Phi-3.5-mini-instruct / zero-shot
# Layer 22
# Macro analysis
# Pearson correlation: -0.43 (p-value: 2.080e-02)
# Spearman correlation: -0.44 (p-value: 1.771e-02)
#
# QASC / Phi-3.5-mini-instruct / zero-shot
# Layer 23
# Macro analysis
# Pearson correlation: -0.43 (p-value: 2.405e-02)
# Spearman correlation: -0.43 (p-value: 2.264e-02)
#
# QASC / Phi-3.5-mini-instruct / zero-shot
# Layer 24
# Macro analysis
# Pearson correlation: -0.44 (p-value: 2.034e-02)
# Spearman correlation: -0.43 (p-value: 2.117e-02)
#
# QASC / Phi-3.5-mini-instruct / zero-shot
# Layer 25
# Macro analysis
# Pearson correlation: -0.46 (p-value: 1.331e-02)
# Spearman correlation: -0.45 (p-value: 1.649e-02)
#
# QASC / Phi-3.5-mini-instruct / zero-shot
# Layer 26
# Macro analysis
# Pearson correlation: -0.46 (p-value: 1.489e-02)
# Spearman correlation: -0.43 (p-value: 2.101e-02)
#
# QASC / Phi-3.5-mini-instruct / zero-shot
# Layer 27
# Macro analysis
# Pearson correlation: -0.44 (p-value: 1.996e-02)
# Spearman correlation: -0.41 (p-value: 2.977e-02)
#
# QASC / Phi-3.5-mini-instruct / zero-shot
# Layer 28
# Macro analysis
# Pearson correlation: -0.44 (p-value: 1.876e-02)
# Spearman correlation: -0.43 (p-value: 2.165e-02)
#
# QASC / Phi-3.5-mini-instruct / zero-shot
# Layer 29
# Macro analysis
# Pearson correlation: -0.42 (p-value: 2.505e-02)
# Spearman correlation: -0.38 (p-value: 4.654e-02)
#
# QASC / Phi-3.5-mini-instruct / zero-shot
# Layer 30
# Macro analysis
# Pearson correlation: -0.43 (p-value: 2.306e-02)
# Spearman correlation: -0.37 (p-value: 5.197e-02)
#
# QASC / Phi-3.5-mini-instruct / zero-shot
# Layer 31
# Macro analysis
# Pearson correlation: -0.39 (p-value: 4.068e-02)
# Spearman correlation: -0.34 (p-value: 7.291e-02)
#
# QASC / Phi-3.5-mini-instruct / zero-shot-cot
# Layer 0
# Macro analysis
# Pearson correlation: -0.40 (p-value: 3.318e-02)
# Spearman correlation: -0.44 (p-value: 2.001e-02)
#
# QASC / Phi-3.5-mini-instruct / zero-shot-cot
# Layer 1
# Macro analysis
# Pearson correlation: -0.34 (p-value: 7.468e-02)
# Spearman correlation: -0.40 (p-value: 3.312e-02)
#
# QASC / Phi-3.5-mini-instruct / zero-shot-cot
# Layer 2
# Macro analysis
# Pearson correlation: -0.42 (p-value: 2.694e-02)
# Spearman correlation: -0.28 (p-value: 1.419e-01)
#
# QASC / Phi-3.5-mini-instruct / zero-shot-cot
# Layer 3
# Macro analysis
# Pearson correlation: -0.52 (p-value: 4.623e-03)
# Spearman correlation: -0.31 (p-value: 1.138e-01)
#
# QASC / Phi-3.5-mini-instruct / zero-shot-cot
# Layer 4
# Macro analysis
# Pearson correlation: -0.55 (p-value: 2.339e-03)
# Spearman correlation: -0.34 (p-value: 8.015e-02)
#
# QASC / Phi-3.5-mini-instruct / zero-shot-cot
# Layer 5
# Macro analysis
# Pearson correlation: -0.58 (p-value: 1.313e-03)
# Spearman correlation: -0.42 (p-value: 2.464e-02)
#
# QASC / Phi-3.5-mini-instruct / zero-shot-cot
# Layer 6
# Macro analysis
# Pearson correlation: -0.69 (p-value: 4.636e-05)
# Spearman correlation: -0.64 (p-value: 2.741e-04)
#
# QASC / Phi-3.5-mini-instruct / zero-shot-cot
# Layer 7
# Macro analysis
# Pearson correlation: -0.69 (p-value: 5.242e-05)
# Spearman correlation: -0.63 (p-value: 3.417e-04)
#
# QASC / Phi-3.5-mini-instruct / zero-shot-cot
# Layer 8
# Macro analysis
# Pearson correlation: -0.67 (p-value: 1.039e-04)
# Spearman correlation: -0.62 (p-value: 3.896e-04)
#
# QASC / Phi-3.5-mini-instruct / zero-shot-cot
# Layer 9
# Macro analysis
# Pearson correlation: -0.66 (p-value: 1.195e-04)
# Spearman correlation: -0.62 (p-value: 4.141e-04)
#
# QASC / Phi-3.5-mini-instruct / zero-shot-cot
# Layer 10
# Macro analysis
# Pearson correlation: -0.69 (p-value: 4.217e-05)
# Spearman correlation: -0.68 (p-value: 7.347e-05)
#
# QASC / Phi-3.5-mini-instruct / zero-shot-cot
# Layer 11
# Macro analysis
# Pearson correlation: -0.68 (p-value: 7.936e-05)
# Spearman correlation: -0.66 (p-value: 1.435e-04)
#
# QASC / Phi-3.5-mini-instruct / zero-shot-cot
# Layer 12
# Macro analysis
# Pearson correlation: -0.69 (p-value: 5.153e-05)
# Spearman correlation: -0.68 (p-value: 6.079e-05)
#
# QASC / Phi-3.5-mini-instruct / zero-shot-cot
# Layer 13
# Macro analysis
# Pearson correlation: -0.67 (p-value: 8.272e-05)
# Spearman correlation: -0.67 (p-value: 8.899e-05)
#
# QASC / Phi-3.5-mini-instruct / zero-shot-cot
# Layer 14
# Macro analysis
# Pearson correlation: -0.66 (p-value: 1.174e-04)
# Spearman correlation: -0.68 (p-value: 7.078e-05)
#
# QASC / Phi-3.5-mini-instruct / zero-shot-cot
# Layer 15
# Macro analysis
# Pearson correlation: -0.64 (p-value: 2.590e-04)
# Spearman correlation: -0.63 (p-value: 2.918e-04)
#
# QASC / Phi-3.5-mini-instruct / zero-shot-cot
# Layer 16
# Macro analysis
# Pearson correlation: -0.48 (p-value: 9.380e-03)
# Spearman correlation: -0.48 (p-value: 9.376e-03)
#
# QASC / Phi-3.5-mini-instruct / zero-shot-cot
# Layer 17
# Macro analysis
# Pearson correlation: -0.52 (p-value: 4.235e-03)
# Spearman correlation: -0.50 (p-value: 7.035e-03)
#
# QASC / Phi-3.5-mini-instruct / zero-shot-cot
# Layer 18
# Macro analysis
# Pearson correlation: -0.60 (p-value: 6.511e-04)
# Spearman correlation: -0.57 (p-value: 1.434e-03)
#
# QASC / Phi-3.5-mini-instruct / zero-shot-cot
# Layer 19
# Macro analysis
# Pearson correlation: -0.68 (p-value: 7.772e-05)
# Spearman correlation: -0.65 (p-value: 1.893e-04)
#
# QASC / Phi-3.5-mini-instruct / zero-shot-cot
# Layer 20
# Macro analysis
# Pearson correlation: -0.65 (p-value: 1.579e-04)
# Spearman correlation: -0.62 (p-value: 4.456e-04)
#
# QASC / Phi-3.5-mini-instruct / zero-shot-cot
# Layer 21
# Macro analysis
# Pearson correlation: -0.76 (p-value: 2.185e-06)
# Spearman correlation: -0.69 (p-value: 4.463e-05)
#
# QASC / Phi-3.5-mini-instruct / zero-shot-cot
# Layer 22
# Macro analysis
# Pearson correlation: -0.76 (p-value: 2.931e-06)
# Spearman correlation: -0.66 (p-value: 1.175e-04)
#
# QASC / Phi-3.5-mini-instruct / zero-shot-cot
# Layer 23
# Macro analysis
# Pearson correlation: -0.77 (p-value: 1.820e-06)
# Spearman correlation: -0.67 (p-value: 9.683e-05)
#
# QASC / Phi-3.5-mini-instruct / zero-shot-cot
# Layer 24
# Macro analysis
# Pearson correlation: -0.77 (p-value: 1.326e-06)
# Spearman correlation: -0.62 (p-value: 4.236e-04)
#
# QASC / Phi-3.5-mini-instruct / zero-shot-cot
# Layer 25
# Macro analysis
# Pearson correlation: -0.77 (p-value: 1.687e-06)
# Spearman correlation: -0.62 (p-value: 4.707e-04)
#
# QASC / Phi-3.5-mini-instruct / zero-shot-cot
# Layer 26
# Macro analysis
# Pearson correlation: -0.77 (p-value: 1.747e-06)
# Spearman correlation: -0.61 (p-value: 5.829e-04)
#
# QASC / Phi-3.5-mini-instruct / zero-shot-cot
# Layer 27
# Macro analysis
# Pearson correlation: -0.77 (p-value: 1.568e-06)
# Spearman correlation: -0.61 (p-value: 5.621e-04)
#
# QASC / Phi-3.5-mini-instruct / zero-shot-cot
# Layer 28
# Macro analysis
# Pearson correlation: -0.78 (p-value: 1.216e-06)
# Spearman correlation: -0.61 (p-value: 5.379e-04)
#
# QASC / Phi-3.5-mini-instruct / zero-shot-cot
# Layer 29
# Macro analysis
# Pearson correlation: -0.77 (p-value: 1.398e-06)
# Spearman correlation: -0.61 (p-value: 5.829e-04)
#
# QASC / Phi-3.5-mini-instruct / zero-shot-cot
# Layer 30
# Macro analysis
# Pearson correlation: -0.77 (p-value: 1.329e-06)
# Spearman correlation: -0.61 (p-value: 5.108e-04)
#
# QASC / Phi-3.5-mini-instruct / zero-shot-cot
# Layer 31
# Macro analysis
# Pearson correlation: -0.76 (p-value: 2.314e-06)
# Spearman correlation: -0.62 (p-value: 4.291e-04)
#
# QASC / Phi-3.5-mini-instruct / few-shot
# Layer 0
# Macro analysis
# Pearson correlation: -0.52 (p-value: 4.680e-03)
# Spearman correlation: -0.44 (p-value: 1.907e-02)
#
# QASC / Phi-3.5-mini-instruct / few-shot
# Layer 1
# Macro analysis
# Pearson correlation: -0.60 (p-value: 6.628e-04)
# Spearman correlation: -0.51 (p-value: 5.835e-03)
#
# QASC / Phi-3.5-mini-instruct / few-shot
# Layer 2
# Macro analysis
# Pearson correlation: -0.53 (p-value: 3.698e-03)
# Spearman correlation: -0.44 (p-value: 1.801e-02)
#
# QASC / Phi-3.5-mini-instruct / few-shot
# Layer 3
# Macro analysis
# Pearson correlation: -0.67 (p-value: 8.887e-05)
# Spearman correlation: -0.67 (p-value: 1.067e-04)
#
# QASC / Phi-3.5-mini-instruct / few-shot
# Layer 4
# Macro analysis
# Pearson correlation: -0.69 (p-value: 4.771e-05)
# Spearman correlation: -0.67 (p-value: 9.062e-05)
#
# QASC / Phi-3.5-mini-instruct / few-shot
# Layer 5
# Macro analysis
# Pearson correlation: -0.71 (p-value: 2.221e-05)
# Spearman correlation: -0.72 (p-value: 1.563e-05)
#
# QASC / Phi-3.5-mini-instruct / few-shot
# Layer 6
# Macro analysis
# Pearson correlation: -0.71 (p-value: 2.177e-05)
# Spearman correlation: -0.72 (p-value: 1.594e-05)
#
# QASC / Phi-3.5-mini-instruct / few-shot
# Layer 7
# Macro analysis
# Pearson correlation: -0.73 (p-value: 1.096e-05)
# Spearman correlation: -0.73 (p-value: 1.170e-05)
#
# QASC / Phi-3.5-mini-instruct / few-shot
# Layer 8
# Macro analysis
# Pearson correlation: -0.71 (p-value: 2.082e-05)
# Spearman correlation: -0.72 (p-value: 1.581e-05)
#
# QASC / Phi-3.5-mini-instruct / few-shot
# Layer 9
# Macro analysis
# Pearson correlation: -0.70 (p-value: 3.316e-05)
# Spearman correlation: -0.73 (p-value: 9.854e-06)
#
# QASC / Phi-3.5-mini-instruct / few-shot
# Layer 10
# Macro analysis
# Pearson correlation: -0.69 (p-value: 5.524e-05)
# Spearman correlation: -0.67 (p-value: 9.654e-05)
#
# QASC / Phi-3.5-mini-instruct / few-shot
# Layer 11
# Macro analysis
# Pearson correlation: -0.67 (p-value: 9.374e-05)
# Spearman correlation: -0.63 (p-value: 2.948e-04)
#
# QASC / Phi-3.5-mini-instruct / few-shot
# Layer 12
# Macro analysis
# Pearson correlation: -0.68 (p-value: 7.573e-05)
# Spearman correlation: -0.63 (p-value: 2.936e-04)
#
# QASC / Phi-3.5-mini-instruct / few-shot
# Layer 13
# Macro analysis
# Pearson correlation: -0.66 (p-value: 1.490e-04)
# Spearman correlation: -0.58 (p-value: 1.203e-03)
#
# QASC / Phi-3.5-mini-instruct / few-shot
# Layer 14
# Macro analysis
# Pearson correlation: -0.63 (p-value: 2.930e-04)
# Spearman correlation: -0.54 (p-value: 2.992e-03)
#
# QASC / Phi-3.5-mini-instruct / few-shot
# Layer 15
# Macro analysis
# Pearson correlation: -0.61 (p-value: 5.131e-04)
# Spearman correlation: -0.55 (p-value: 2.574e-03)
#
# QASC / Phi-3.5-mini-instruct / few-shot
# Layer 16
# Macro analysis
# Pearson correlation: -0.65 (p-value: 1.751e-04)
# Spearman correlation: -0.65 (p-value: 1.577e-04)
#
# QASC / Phi-3.5-mini-instruct / few-shot
# Layer 17
# Macro analysis
# Pearson correlation: -0.68 (p-value: 8.014e-05)
# Spearman correlation: -0.74 (p-value: 5.978e-06)
#
# QASC / Phi-3.5-mini-instruct / few-shot
# Layer 18
# Macro analysis
# Pearson correlation: -0.64 (p-value: 2.506e-04)
# Spearman correlation: -0.68 (p-value: 6.850e-05)
#
# QASC / Phi-3.5-mini-instruct / few-shot
# Layer 19
# Macro analysis
# Pearson correlation: -0.59 (p-value: 8.524e-04)
# Spearman correlation: -0.60 (p-value: 7.438e-04)
#
# QASC / Phi-3.5-mini-instruct / few-shot
# Layer 20
# Macro analysis
# Pearson correlation: -0.55 (p-value: 2.381e-03)
# Spearman correlation: -0.55 (p-value: 2.700e-03)
#
# QASC / Phi-3.5-mini-instruct / few-shot
# Layer 21
# Macro analysis
# Pearson correlation: -0.53 (p-value: 3.991e-03)
# Spearman correlation: -0.49 (p-value: 7.675e-03)
#
# QASC / Phi-3.5-mini-instruct / few-shot
# Layer 22
# Macro analysis
# Pearson correlation: -0.52 (p-value: 4.129e-03)
# Spearman correlation: -0.52 (p-value: 4.664e-03)
#
# QASC / Phi-3.5-mini-instruct / few-shot
# Layer 23
# Macro analysis
# Pearson correlation: -0.52 (p-value: 4.372e-03)
# Spearman correlation: -0.54 (p-value: 3.006e-03)
#
# QASC / Phi-3.5-mini-instruct / few-shot
# Layer 24
# Macro analysis
# Pearson correlation: -0.51 (p-value: 5.050e-03)
# Spearman correlation: -0.51 (p-value: 5.236e-03)
#
# QASC / Phi-3.5-mini-instruct / few-shot
# Layer 25
# Macro analysis
# Pearson correlation: -0.50 (p-value: 6.295e-03)
# Spearman correlation: -0.47 (p-value: 1.101e-02)
#
# QASC / Phi-3.5-mini-instruct / few-shot
# Layer 26
# Macro analysis
# Pearson correlation: -0.50 (p-value: 6.140e-03)
# Spearman correlation: -0.46 (p-value: 1.281e-02)
#
# QASC / Phi-3.5-mini-instruct / few-shot
# Layer 27
# Macro analysis
# Pearson correlation: -0.52 (p-value: 4.488e-03)
# Spearman correlation: -0.51 (p-value: 6.079e-03)
#
# QASC / Phi-3.5-mini-instruct / few-shot
# Layer 28
# Macro analysis
# Pearson correlation: -0.55 (p-value: 2.515e-03)
# Spearman correlation: -0.55 (p-value: 2.284e-03)
#
# QASC / Phi-3.5-mini-instruct / few-shot
# Layer 29
# Macro analysis
# Pearson correlation: -0.57 (p-value: 1.573e-03)
# Spearman correlation: -0.57 (p-value: 1.596e-03)
#
# QASC / Phi-3.5-mini-instruct / few-shot
# Layer 30
# Macro analysis
# Pearson correlation: -0.57 (p-value: 1.682e-03)
# Spearman correlation: -0.56 (p-value: 2.133e-03)
#
# QASC / Phi-3.5-mini-instruct / few-shot
# Layer 31
# Macro analysis
# Pearson correlation: -0.58 (p-value: 1.158e-03)
# Spearman correlation: -0.54 (p-value: 2.876e-03)
#
# QASC / Phi-3.5-mini-instruct / few-shot-cot
# Layer 0
# Macro analysis
# Pearson correlation: -0.28 (p-value: 1.518e-01)
# Spearman correlation: -0.18 (p-value: 3.694e-01)
#
# QASC / Phi-3.5-mini-instruct / few-shot-cot
# Layer 1
# Macro analysis
# Pearson correlation: -0.34 (p-value: 7.387e-02)
# Spearman correlation: -0.20 (p-value: 2.973e-01)
#
# QASC / Phi-3.5-mini-instruct / few-shot-cot
# Layer 2
# Macro analysis
# Pearson correlation: -0.30 (p-value: 1.205e-01)
# Spearman correlation: -0.17 (p-value: 3.805e-01)
#
# QASC / Phi-3.5-mini-instruct / few-shot-cot
# Layer 3
# Macro analysis
# Pearson correlation: -0.31 (p-value: 1.054e-01)
# Spearman correlation: -0.16 (p-value: 4.176e-01)
#
# QASC / Phi-3.5-mini-instruct / few-shot-cot
# Layer 4
# Macro analysis
# Pearson correlation: -0.33 (p-value: 8.297e-02)
# Spearman correlation: -0.19 (p-value: 3.288e-01)
#
# QASC / Phi-3.5-mini-instruct / few-shot-cot
# Layer 5
# Macro analysis
# Pearson correlation: -0.33 (p-value: 8.270e-02)
# Spearman correlation: -0.24 (p-value: 2.222e-01)
#
# QASC / Phi-3.5-mini-instruct / few-shot-cot
# Layer 6
# Macro analysis
# Pearson correlation: -0.33 (p-value: 9.083e-02)
# Spearman correlation: -0.21 (p-value: 2.798e-01)
#
# QASC / Phi-3.5-mini-instruct / few-shot-cot
# Layer 7
# Macro analysis
# Pearson correlation: -0.32 (p-value: 9.971e-02)
# Spearman correlation: -0.22 (p-value: 2.684e-01)
#
# QASC / Phi-3.5-mini-instruct / few-shot-cot
# Layer 8
# Macro analysis
# Pearson correlation: -0.30 (p-value: 1.164e-01)
# Spearman correlation: -0.19 (p-value: 3.218e-01)
#
# QASC / Phi-3.5-mini-instruct / few-shot-cot
# Layer 9
# Macro analysis
# Pearson correlation: -0.28 (p-value: 1.480e-01)
# Spearman correlation: -0.19 (p-value: 3.253e-01)
#
# QASC / Phi-3.5-mini-instruct / few-shot-cot
# Layer 10
# Macro analysis
# Pearson correlation: -0.30 (p-value: 1.189e-01)
# Spearman correlation: -0.20 (p-value: 3.094e-01)
#
# QASC / Phi-3.5-mini-instruct / few-shot-cot
# Layer 11
# Macro analysis
# Pearson correlation: -0.32 (p-value: 9.372e-02)
# Spearman correlation: -0.20 (p-value: 3.190e-01)
#
# QASC / Phi-3.5-mini-instruct / few-shot-cot
# Layer 12
# Macro analysis
# Pearson correlation: -0.34 (p-value: 7.590e-02)
# Spearman correlation: -0.27 (p-value: 1.691e-01)
#
# QASC / Phi-3.5-mini-instruct / few-shot-cot
# Layer 13
# Macro analysis
# Pearson correlation: -0.36 (p-value: 6.337e-02)
# Spearman correlation: -0.24 (p-value: 2.203e-01)
#
# QASC / Phi-3.5-mini-instruct / few-shot-cot
# Layer 14
# Macro analysis
# Pearson correlation: -0.35 (p-value: 6.707e-02)
# Spearman correlation: -0.23 (p-value: 2.299e-01)
#
# QASC / Phi-3.5-mini-instruct / few-shot-cot
# Layer 15
# Macro analysis
# Pearson correlation: -0.35 (p-value: 6.634e-02)
# Spearman correlation: -0.24 (p-value: 2.119e-01)
#
# QASC / Phi-3.5-mini-instruct / few-shot-cot
# Layer 16
# Macro analysis
# Pearson correlation: -0.37 (p-value: 5.132e-02)
# Spearman correlation: -0.27 (p-value: 1.598e-01)
#
# QASC / Phi-3.5-mini-instruct / few-shot-cot
# Layer 17
# Macro analysis
# Pearson correlation: -0.38 (p-value: 4.857e-02)
# Spearman correlation: -0.28 (p-value: 1.524e-01)
#
# QASC / Phi-3.5-mini-instruct / few-shot-cot
# Layer 18
# Macro analysis
# Pearson correlation: -0.37 (p-value: 5.499e-02)
# Spearman correlation: -0.25 (p-value: 1.950e-01)
#
# QASC / Phi-3.5-mini-instruct / few-shot-cot
# Layer 19
# Macro analysis
# Pearson correlation: -0.37 (p-value: 5.036e-02)
# Spearman correlation: -0.29 (p-value: 1.386e-01)
#
# QASC / Phi-3.5-mini-instruct / few-shot-cot
# Layer 20
# Macro analysis
# Pearson correlation: -0.34 (p-value: 7.974e-02)
# Spearman correlation: -0.27 (p-value: 1.628e-01)
#
# QASC / Phi-3.5-mini-instruct / few-shot-cot
# Layer 21
# Macro analysis
# Pearson correlation: -0.36 (p-value: 6.258e-02)
# Spearman correlation: -0.28 (p-value: 1.533e-01)
#
# QASC / Phi-3.5-mini-instruct / few-shot-cot
# Layer 22
# Macro analysis
# Pearson correlation: -0.33 (p-value: 8.565e-02)
# Spearman correlation: -0.20 (p-value: 3.193e-01)
#
# QASC / Phi-3.5-mini-instruct / few-shot-cot
# Layer 23
# Macro analysis
# Pearson correlation: -0.34 (p-value: 7.738e-02)
# Spearman correlation: -0.23 (p-value: 2.294e-01)
#
# QASC / Phi-3.5-mini-instruct / few-shot-cot
# Layer 24
# Macro analysis
# Pearson correlation: -0.37 (p-value: 5.534e-02)
# Spearman correlation: -0.27 (p-value: 1.673e-01)
#
# QASC / Phi-3.5-mini-instruct / few-shot-cot
# Layer 25
# Macro analysis
# Pearson correlation: -0.36 (p-value: 5.869e-02)
# Spearman correlation: -0.26 (p-value: 1.855e-01)
#
# QASC / Phi-3.5-mini-instruct / few-shot-cot
# Layer 26
# Macro analysis
# Pearson correlation: -0.37 (p-value: 5.587e-02)
# Spearman correlation: -0.27 (p-value: 1.606e-01)
#
# QASC / Phi-3.5-mini-instruct / few-shot-cot
# Layer 27
# Macro analysis
# Pearson correlation: -0.36 (p-value: 6.057e-02)
# Spearman correlation: -0.27 (p-value: 1.646e-01)
#
# QASC / Phi-3.5-mini-instruct / few-shot-cot
# Layer 28
# Macro analysis
# Pearson correlation: -0.36 (p-value: 5.634e-02)
# Spearman correlation: -0.28 (p-value: 1.542e-01)
#
# QASC / Phi-3.5-mini-instruct / few-shot-cot
# Layer 29
# Macro analysis
# Pearson correlation: -0.38 (p-value: 4.896e-02)
# Spearman correlation: -0.26 (p-value: 1.877e-01)
#
# QASC / Phi-3.5-mini-instruct / few-shot-cot
# Layer 30
# Macro analysis
# Pearson correlation: -0.39 (p-value: 4.081e-02)
# Spearman correlation: -0.26 (p-value: 1.779e-01)
#
# QASC / Phi-3.5-mini-instruct / few-shot-cot
# Layer 31
# Macro analysis
# Pearson correlation: -0.41 (p-value: 3.247e-02)
# Spearman correlation: -0.31 (p-value: 1.096e-01)
#
# 100TFQA / Phi-3.5-mini-instruct / zero-shot
# Layer 0
# Macro analysis
# Pearson correlation: -0.83 (p-value: 3.437e-08)
# Spearman correlation: -0.79 (p-value: 5.565e-07)
#
# 100TFQA / Phi-3.5-mini-instruct / zero-shot
# Layer 1
# Macro analysis
# Pearson correlation: -0.89 (p-value: 2.424e-10)
# Spearman correlation: -0.87 (p-value: 1.650e-09)
#
# 100TFQA / Phi-3.5-mini-instruct / zero-shot
# Layer 2
# Macro analysis
# Pearson correlation: -0.16 (p-value: 4.107e-01)
# Spearman correlation: -0.17 (p-value: 3.961e-01)
#
# 100TFQA / Phi-3.5-mini-instruct / zero-shot
# Layer 3
# Macro analysis
# Pearson correlation: -0.19 (p-value: 3.291e-01)
# Spearman correlation: -0.18 (p-value: 3.523e-01)
#
# 100TFQA / Phi-3.5-mini-instruct / zero-shot
# Layer 4
# Macro analysis
# Pearson correlation: -0.29 (p-value: 1.305e-01)
# Spearman correlation: -0.25 (p-value: 1.909e-01)
#
# 100TFQA / Phi-3.5-mini-instruct / zero-shot
# Layer 5
# Macro analysis
# Pearson correlation: -0.37 (p-value: 4.998e-02)
# Spearman correlation: -0.39 (p-value: 4.244e-02)
#
# 100TFQA / Phi-3.5-mini-instruct / zero-shot
# Layer 6
# Macro analysis
# Pearson correlation: -0.32 (p-value: 9.314e-02)
# Spearman correlation: -0.31 (p-value: 1.117e-01)
#
# 100TFQA / Phi-3.5-mini-instruct / zero-shot
# Layer 7
# Macro analysis
# Pearson correlation: -0.38 (p-value: 4.536e-02)
# Spearman correlation: -0.43 (p-value: 2.114e-02)
#
# 100TFQA / Phi-3.5-mini-instruct / zero-shot
# Layer 8
# Macro analysis
# Pearson correlation: -0.50 (p-value: 7.336e-03)
# Spearman correlation: -0.65 (p-value: 1.777e-04)
#
# 100TFQA / Phi-3.5-mini-instruct / zero-shot
# Layer 9
# Macro analysis
# Pearson correlation: -0.47 (p-value: 1.105e-02)
# Spearman correlation: -0.61 (p-value: 6.308e-04)
#
# 100TFQA / Phi-3.5-mini-instruct / zero-shot
# Layer 10
# Macro analysis
# Pearson correlation: -0.49 (p-value: 7.645e-03)
# Spearman correlation: -0.59 (p-value: 8.821e-04)
#
# 100TFQA / Phi-3.5-mini-instruct / zero-shot
# Layer 11
# Macro analysis
# Pearson correlation: -0.52 (p-value: 4.135e-03)
# Spearman correlation: -0.50 (p-value: 7.303e-03)
#
# 100TFQA / Phi-3.5-mini-instruct / zero-shot
# Layer 12
# Macro analysis
# Pearson correlation: -0.28 (p-value: 1.524e-01)
# Spearman correlation: -0.31 (p-value: 1.106e-01)
#
# 100TFQA / Phi-3.5-mini-instruct / zero-shot
# Layer 13
# Macro analysis
# Pearson correlation: -0.24 (p-value: 2.220e-01)
# Spearman correlation: -0.27 (p-value: 1.671e-01)
#
# 100TFQA / Phi-3.5-mini-instruct / zero-shot
# Layer 14
# Macro analysis
# Pearson correlation: -0.23 (p-value: 2.467e-01)
# Spearman correlation: -0.26 (p-value: 1.761e-01)
#
# 100TFQA / Phi-3.5-mini-instruct / zero-shot
# Layer 15
# Macro analysis
# Pearson correlation: -0.27 (p-value: 1.627e-01)
# Spearman correlation: -0.25 (p-value: 2.063e-01)
#
# 100TFQA / Phi-3.5-mini-instruct / zero-shot
# Layer 16
# Macro analysis
# Pearson correlation: -0.34 (p-value: 7.991e-02)
# Spearman correlation: -0.30 (p-value: 1.225e-01)
#
# 100TFQA / Phi-3.5-mini-instruct / zero-shot
# Layer 17
# Macro analysis
# Pearson correlation: -0.34 (p-value: 7.700e-02)
# Spearman correlation: -0.28 (p-value: 1.534e-01)
#
# 100TFQA / Phi-3.5-mini-instruct / zero-shot
# Layer 18
# Macro analysis
# Pearson correlation: -0.33 (p-value: 8.331e-02)
# Spearman correlation: -0.29 (p-value: 1.289e-01)
#
# 100TFQA / Phi-3.5-mini-instruct / zero-shot
# Layer 19
# Macro analysis
# Pearson correlation: -0.37 (p-value: 5.509e-02)
# Spearman correlation: -0.33 (p-value: 8.373e-02)
#
# 100TFQA / Phi-3.5-mini-instruct / zero-shot
# Layer 20
# Macro analysis
# Pearson correlation: -0.36 (p-value: 5.935e-02)
# Spearman correlation: -0.32 (p-value: 9.407e-02)
#
# 100TFQA / Phi-3.5-mini-instruct / zero-shot
# Layer 21
# Macro analysis
# Pearson correlation: -0.38 (p-value: 4.498e-02)
# Spearman correlation: -0.33 (p-value: 8.585e-02)
#
# 100TFQA / Phi-3.5-mini-instruct / zero-shot
# Layer 22
# Macro analysis
# Pearson correlation: -0.39 (p-value: 4.108e-02)
# Spearman correlation: -0.33 (p-value: 8.192e-02)
#
# 100TFQA / Phi-3.5-mini-instruct / zero-shot
# Layer 23
# Macro analysis
# Pearson correlation: -0.40 (p-value: 3.351e-02)
# Spearman correlation: -0.38 (p-value: 4.312e-02)
#
# 100TFQA / Phi-3.5-mini-instruct / zero-shot
# Layer 24
# Macro analysis
# Pearson correlation: -0.45 (p-value: 1.706e-02)
# Spearman correlation: -0.42 (p-value: 2.465e-02)
#
# 100TFQA / Phi-3.5-mini-instruct / zero-shot
# Layer 25
# Macro analysis
# Pearson correlation: -0.54 (p-value: 3.090e-03)
# Spearman correlation: -0.48 (p-value: 9.414e-03)
#
# 100TFQA / Phi-3.5-mini-instruct / zero-shot
# Layer 26
# Macro analysis
# Pearson correlation: -0.56 (p-value: 1.864e-03)
# Spearman correlation: -0.51 (p-value: 5.538e-03)
#
# 100TFQA / Phi-3.5-mini-instruct / zero-shot
# Layer 27
# Macro analysis
# Pearson correlation: -0.56 (p-value: 2.076e-03)
# Spearman correlation: -0.48 (p-value: 9.115e-03)
#
# 100TFQA / Phi-3.5-mini-instruct / zero-shot
# Layer 28
# Macro analysis
# Pearson correlation: -0.55 (p-value: 2.306e-03)
# Spearman correlation: -0.48 (p-value: 9.137e-03)
#
# 100TFQA / Phi-3.5-mini-instruct / zero-shot
# Layer 29
# Macro analysis
# Pearson correlation: -0.57 (p-value: 1.569e-03)
# Spearman correlation: -0.50 (p-value: 6.467e-03)
#
# 100TFQA / Phi-3.5-mini-instruct / zero-shot
# Layer 30
# Macro analysis
# Pearson correlation: -0.56 (p-value: 1.900e-03)
# Spearman correlation: -0.51 (p-value: 6.100e-03)
#
# 100TFQA / Phi-3.5-mini-instruct / zero-shot
# Layer 31
# Macro analysis
# Pearson correlation: -0.38 (p-value: 4.917e-02)
# Spearman correlation: -0.41 (p-value: 2.934e-02)
#
# 100TFQA / Phi-3.5-mini-instruct / zero-shot-cot
# Layer 0
# Macro analysis
# Pearson correlation: -0.18 (p-value: 3.728e-01)
# Spearman correlation: -0.09 (p-value: 6.460e-01)
#
# 100TFQA / Phi-3.5-mini-instruct / zero-shot-cot
# Layer 1
# Macro analysis
# Pearson correlation: -0.15 (p-value: 4.443e-01)
# Spearman correlation: -0.08 (p-value: 6.881e-01)
#
# 100TFQA / Phi-3.5-mini-instruct / zero-shot-cot
# Layer 2
# Macro analysis
# Pearson correlation: -0.36 (p-value: 5.641e-02)
# Spearman correlation: -0.35 (p-value: 7.073e-02)
#
# 100TFQA / Phi-3.5-mini-instruct / zero-shot-cot
# Layer 3
# Macro analysis
# Pearson correlation: -0.35 (p-value: 6.406e-02)
# Spearman correlation: -0.35 (p-value: 6.977e-02)
#
# 100TFQA / Phi-3.5-mini-instruct / zero-shot-cot
# Layer 4
# Macro analysis
# Pearson correlation: -0.41 (p-value: 3.125e-02)
# Spearman correlation: -0.39 (p-value: 3.954e-02)
#
# 100TFQA / Phi-3.5-mini-instruct / zero-shot-cot
# Layer 5
# Macro analysis
# Pearson correlation: -0.40 (p-value: 3.745e-02)
# Spearman correlation: -0.39 (p-value: 3.812e-02)
#
# 100TFQA / Phi-3.5-mini-instruct / zero-shot-cot
# Layer 6
# Macro analysis
# Pearson correlation: -0.41 (p-value: 2.979e-02)
# Spearman correlation: -0.38 (p-value: 4.553e-02)
#
# 100TFQA / Phi-3.5-mini-instruct / zero-shot-cot
# Layer 7
# Macro analysis
# Pearson correlation: -0.38 (p-value: 4.545e-02)
# Spearman correlation: -0.32 (p-value: 9.637e-02)
#
# 100TFQA / Phi-3.5-mini-instruct / zero-shot-cot
# Layer 8
# Macro analysis
# Pearson correlation: -0.32 (p-value: 9.563e-02)
# Spearman correlation: -0.26 (p-value: 1.863e-01)
#
# 100TFQA / Phi-3.5-mini-instruct / zero-shot-cot
# Layer 9
# Macro analysis
# Pearson correlation: -0.31 (p-value: 1.078e-01)
# Spearman correlation: -0.25 (p-value: 2.067e-01)
#
# 100TFQA / Phi-3.5-mini-instruct / zero-shot-cot
# Layer 10
# Macro analysis
# Pearson correlation: -0.26 (p-value: 1.783e-01)
# Spearman correlation: -0.22 (p-value: 2.607e-01)
#
# 100TFQA / Phi-3.5-mini-instruct / zero-shot-cot
# Layer 11
# Macro analysis
# Pearson correlation: -0.17 (p-value: 3.816e-01)
# Spearman correlation: -0.14 (p-value: 4.763e-01)
#
# 100TFQA / Phi-3.5-mini-instruct / zero-shot-cot
# Layer 12
# Macro analysis
# Pearson correlation: -0.14 (p-value: 4.824e-01)
# Spearman correlation: -0.12 (p-value: 5.346e-01)
#
# 100TFQA / Phi-3.5-mini-instruct / zero-shot-cot
# Layer 13
# Macro analysis
# Pearson correlation: -0.16 (p-value: 4.150e-01)
# Spearman correlation: -0.19 (p-value: 3.397e-01)
#
# 100TFQA / Phi-3.5-mini-instruct / zero-shot-cot
# Layer 14
# Macro analysis
# Pearson correlation: -0.19 (p-value: 3.374e-01)
# Spearman correlation: -0.23 (p-value: 2.402e-01)
#
# 100TFQA / Phi-3.5-mini-instruct / zero-shot-cot
# Layer 15
# Macro analysis
# Pearson correlation: -0.19 (p-value: 3.432e-01)
# Spearman correlation: -0.20 (p-value: 3.181e-01)
#
# 100TFQA / Phi-3.5-mini-instruct / zero-shot-cot
# Layer 16
# Macro analysis
# Pearson correlation: -0.29 (p-value: 1.331e-01)
# Spearman correlation: -0.28 (p-value: 1.509e-01)
#
# 100TFQA / Phi-3.5-mini-instruct / zero-shot-cot
# Layer 17
# Macro analysis
# Pearson correlation: -0.34 (p-value: 7.912e-02)
# Spearman correlation: -0.32 (p-value: 1.020e-01)
#
# 100TFQA / Phi-3.5-mini-instruct / zero-shot-cot
# Layer 18
# Macro analysis
# Pearson correlation: -0.38 (p-value: 4.868e-02)
# Spearman correlation: -0.38 (p-value: 4.381e-02)
#
# 100TFQA / Phi-3.5-mini-instruct / zero-shot-cot
# Layer 19
# Macro analysis
# Pearson correlation: -0.44 (p-value: 1.935e-02)
# Spearman correlation: -0.45 (p-value: 1.759e-02)
#
# 100TFQA / Phi-3.5-mini-instruct / zero-shot-cot
# Layer 20
# Macro analysis
# Pearson correlation: -0.51 (p-value: 5.270e-03)
# Spearman correlation: -0.52 (p-value: 4.604e-03)
#
# 100TFQA / Phi-3.5-mini-instruct / zero-shot-cot
# Layer 21
# Macro analysis
# Pearson correlation: -0.52 (p-value: 4.345e-03)
# Spearman correlation: -0.52 (p-value: 4.787e-03)
#
# 100TFQA / Phi-3.5-mini-instruct / zero-shot-cot
# Layer 22
# Macro analysis
# Pearson correlation: -0.54 (p-value: 2.828e-03)
# Spearman correlation: -0.54 (p-value: 2.731e-03)
#
# 100TFQA / Phi-3.5-mini-instruct / zero-shot-cot
# Layer 23
# Macro analysis
# Pearson correlation: -0.51 (p-value: 6.126e-03)
# Spearman correlation: -0.52 (p-value: 4.328e-03)
#
# 100TFQA / Phi-3.5-mini-instruct / zero-shot-cot
# Layer 24
# Macro analysis
# Pearson correlation: -0.52 (p-value: 4.445e-03)
# Spearman correlation: -0.56 (p-value: 2.058e-03)
#
# 100TFQA / Phi-3.5-mini-instruct / zero-shot-cot
# Layer 25
# Macro analysis
# Pearson correlation: -0.52 (p-value: 4.915e-03)
# Spearman correlation: -0.56 (p-value: 2.042e-03)
#
# 100TFQA / Phi-3.5-mini-instruct / zero-shot-cot
# Layer 26
# Macro analysis
# Pearson correlation: -0.49 (p-value: 8.553e-03)
# Spearman correlation: -0.57 (p-value: 1.674e-03)
#
# 100TFQA / Phi-3.5-mini-instruct / zero-shot-cot
# Layer 27
# Macro analysis
# Pearson correlation: -0.48 (p-value: 9.719e-03)
# Spearman correlation: -0.56 (p-value: 1.825e-03)
#
# 100TFQA / Phi-3.5-mini-instruct / zero-shot-cot
# Layer 28
# Macro analysis
# Pearson correlation: -0.48 (p-value: 1.024e-02)
# Spearman correlation: -0.55 (p-value: 2.274e-03)
#
# 100TFQA / Phi-3.5-mini-instruct / zero-shot-cot
# ...
# Layer 2
# Macro analysis
# Pearson correlation: -0.42 (p-value: 2.646e-02)
# Spearman correlation: -0.42 (p-value: 2.522e-02)
#
# 100TFQA / Llama-3.1-8B-Instruct / few-shot-cot
# Layer 3
# Macro analysis
# Pearson correlation: -0.40 (p-value: 3.621e-02)
# Spearman correlation: -0.35 (p-value: 6.959e-02)
#
# 100TFQA / Llama-3.1-8B-Instruct / few-shot-cot
# Layer 4
# Macro analysis
# Pearson correlation: -0.40 (p-value: 3.478e-02)
# Spearman correlation: -0.34 (p-value: 8.061e-02)
#
# 100TFQA / Llama-3.1-8B-Instruct / few-shot-cot
# Layer 5
# Macro analysis
# Pearson correlation: -0.41 (p-value: 3.157e-02)
# Spearman correlation: -0.34 (p-value: 7.445e-02)
#
# 100TFQA / Llama-3.1-8B-Instruct / few-shot-cot
# Layer 6
# Macro analysis
# Pearson correlation: -0.38 (p-value: 4.481e-02)
# Spearman correlation: -0.32 (p-value: 9.290e-02)
#
# 100TFQA / Llama-3.1-8B-Instruct / few-shot-cot
# Layer 7
# Macro analysis
# Pearson correlation: -0.33 (p-value: 9.020e-02)
# Spearman correlation: -0.32 (p-value: 9.987e-02)
#
# 100TFQA / Llama-3.1-8B-Instruct / few-shot-cot
# Layer 8
# Macro analysis
# Pearson correlation: -0.31 (p-value: 1.134e-01)
# Spearman correlation: -0.30 (p-value: 1.224e-01)
#
# 100TFQA / Llama-3.1-8B-Instruct / few-shot-cot
# Layer 9
# Macro analysis
# Pearson correlation: -0.27 (p-value: 1.578e-01)
# Spearman correlation: -0.24 (p-value: 2.131e-01)
#
# 100TFQA / Llama-3.1-8B-Instruct / few-shot-cot
# Layer 10
# Macro analysis
# Pearson correlation: -0.29 (p-value: 1.278e-01)
# Spearman correlation: -0.26 (p-value: 1.754e-01)
#
# 100TFQA / Llama-3.1-8B-Instruct / few-shot-cot
# Layer 11
# Macro analysis
# Pearson correlation: -0.31 (p-value: 1.067e-01)
# Spearman correlation: -0.27 (p-value: 1.578e-01)
#
# 100TFQA / Llama-3.1-8B-Instruct / few-shot-cot
# Layer 12
# Macro analysis
# Pearson correlation: -0.31 (p-value: 1.052e-01)
# Spearman correlation: -0.28 (p-value: 1.419e-01)
#
# 100TFQA / Llama-3.1-8B-Instruct / few-shot-cot
# Layer 13
# Macro analysis
# Pearson correlation: -0.28 (p-value: 1.441e-01)
# Spearman correlation: -0.24 (p-value: 2.152e-01)
#
# 100TFQA / Llama-3.1-8B-Instruct / few-shot-cot
# Layer 14
# Macro analysis
# Pearson correlation: -0.28 (p-value: 1.526e-01)
# Spearman correlation: -0.27 (p-value: 1.606e-01)
#
# 100TFQA / Llama-3.1-8B-Instruct / few-shot-cot
# Layer 15
# Macro analysis
# Pearson correlation: -0.33 (p-value: 8.285e-02)
# Spearman correlation: -0.34 (p-value: 7.899e-02)
#
# 100TFQA / Llama-3.1-8B-Instruct / few-shot-cot
# Layer 16
# Macro analysis
# Pearson correlation: -0.35 (p-value: 6.512e-02)
# Spearman correlation: -0.35 (p-value: 7.175e-02)
#
# 100TFQA / Llama-3.1-8B-Instruct / few-shot-cot
# Layer 17
# Macro analysis
# Pearson correlation: -0.39 (p-value: 3.928e-02)
# Spearman correlation: -0.36 (p-value: 6.220e-02)
#
# 100TFQA / Llama-3.1-8B-Instruct / few-shot-cot
# Layer 18
# Macro analysis
# Pearson correlation: -0.40 (p-value: 3.431e-02)
# Spearman correlation: -0.37 (p-value: 5.184e-02)
#
# 100TFQA / Llama-3.1-8B-Instruct / few-shot-cot
# Layer 19
# Macro analysis
# Pearson correlation: -0.38 (p-value: 4.906e-02)
# Spearman correlation: -0.35 (p-value: 7.151e-02)
#
# 100TFQA / Llama-3.1-8B-Instruct / few-shot-cot
# Layer 20
# Macro analysis
# Pearson correlation: -0.36 (p-value: 5.792e-02)
# Spearman correlation: -0.34 (p-value: 8.136e-02)
#
# 100TFQA / Llama-3.1-8B-Instruct / few-shot-cot
# Layer 21
# Macro analysis
# Pearson correlation: -0.37 (p-value: 5.229e-02)
# Spearman correlation: -0.34 (p-value: 7.646e-02)
#
# 100TFQA / Llama-3.1-8B-Instruct / few-shot-cot
# Layer 22
# Macro analysis
# Pearson correlation: -0.34 (p-value: 7.350e-02)
# Spearman correlation: -0.33 (p-value: 8.203e-02)
#
# 100TFQA / Llama-3.1-8B-Instruct / few-shot-cot
# Layer 23
# Macro analysis
# Pearson correlation: -0.35 (p-value: 6.827e-02)
# Spearman correlation: -0.33 (p-value: 8.203e-02)
#
# 100TFQA / Llama-3.1-8B-Instruct / few-shot-cot
# Layer 24
# Macro analysis
# Pearson correlation: -0.34 (p-value: 7.569e-02)
# Spearman correlation: -0.33 (p-value: 8.410e-02)
#
# 100TFQA / Llama-3.1-8B-Instruct / few-shot-cot
# Layer 25
# Macro analysis
# Pearson correlation: -0.33 (p-value: 8.213e-02)
# Spearman correlation: -0.30 (p-value: 1.157e-01)
#
# 100TFQA / Llama-3.1-8B-Instruct / few-shot-cot
# Layer 26
# Macro analysis
# Pearson correlation: -0.34 (p-value: 7.601e-02)
# Spearman correlation: -0.31 (p-value: 1.030e-01)
#
# 100TFQA / Llama-3.1-8B-Instruct / few-shot-cot
# Layer 27
# Macro analysis
# Pearson correlation: -0.29 (p-value: 1.357e-01)
# Spearman correlation: -0.27 (p-value: 1.578e-01)
#
# 100TFQA / Llama-3.1-8B-Instruct / few-shot-cot
# Layer 28
# Macro analysis
# Pearson correlation: -0.29 (p-value: 1.279e-01)
# Spearman correlation: -0.27 (p-value: 1.600e-01)
#
# 100TFQA / Llama-3.1-8B-Instruct / few-shot-cot
# Layer 29
# Macro analysis
# Pearson correlation: -0.31 (p-value: 1.123e-01)
# Spearman correlation: -0.27 (p-value: 1.653e-01)
#
# 100TFQA / Llama-3.1-8B-Instruct / few-shot-cot
# Layer 30
# Macro analysis
# Pearson correlation: -0.33 (p-value: 8.822e-02)
# Spearman correlation: -0.31 (p-value: 1.033e-01)
#
# 100TFQA / Llama-3.1-8B-Instruct / few-shot-cot
# Layer 31
# Macro analysis
# Pearson correlation: -0.37 (p-value: 5.287e-02)
# Spearman correlation: -0.33 (p-value: 8.771e-02)
#
# [Errno 2] No such file or directory: '../../../results/GSM8K/Llama-3.1-8B-Instruct/zero-shot_layer_wise_hidden_states.conf'
# GSM8K / Llama-3.1-8B-Instruct / zero-shot-cot
# Layer 0
# Macro analysis
# Pearson correlation: 0.08 (p-value: 7.007e-01)
# Spearman correlation: -0.08 (p-value: 6.732e-01)
#
# GSM8K / Llama-3.1-8B-Instruct / zero-shot-cot
# Layer 1
# Macro analysis
# Pearson correlation: 0.07 (p-value: 7.133e-01)
# Spearman correlation: -0.08 (p-value: 6.829e-01)
#
# GSM8K / Llama-3.1-8B-Instruct / zero-shot-cot
# Layer 2
# Macro analysis
# Pearson correlation: -0.02 (p-value: 9.231e-01)
# Spearman correlation: -0.13 (p-value: 5.253e-01)
#
# GSM8K / Llama-3.1-8B-Instruct / zero-shot-cot
# Layer 3
# Macro analysis
# Pearson correlation: -0.04 (p-value: 8.536e-01)
# Spearman correlation: -0.14 (p-value: 4.917e-01)
#
# GSM8K / Llama-3.1-8B-Instruct / zero-shot-cot
# Layer 4
# Macro analysis
# Pearson correlation: -0.11 (p-value: 5.654e-01)
# Spearman correlation: -0.18 (p-value: 3.657e-01)
#
# GSM8K / Llama-3.1-8B-Instruct / zero-shot-cot
# Layer 5
# Macro analysis
# Pearson correlation: -0.13 (p-value: 4.980e-01)
# Spearman correlation: -0.22 (p-value: 2.513e-01)
#
# GSM8K / Llama-3.1-8B-Instruct / zero-shot-cot
# Layer 6
# Macro analysis
# Pearson correlation: -0.12 (p-value: 5.532e-01)
# Spearman correlation: -0.22 (p-value: 2.610e-01)
#
# GSM8K / Llama-3.1-8B-Instruct / zero-shot-cot
# Layer 7
# Macro analysis
# Pearson correlation: -0.12 (p-value: 5.288e-01)
# Spearman correlation: -0.24 (p-value: 2.272e-01)
#
# GSM8K / Llama-3.1-8B-Instruct / zero-shot-cot
# Layer 8
# Macro analysis
# Pearson correlation: -0.12 (p-value: 5.364e-01)
# Spearman correlation: -0.20 (p-value: 3.105e-01)
#
# GSM8K / Llama-3.1-8B-Instruct / zero-shot-cot
# Layer 9
# Macro analysis
# Pearson correlation: -0.14 (p-value: 4.898e-01)
# Spearman correlation: -0.24 (p-value: 2.184e-01)
#
# GSM8K / Llama-3.1-8B-Instruct / zero-shot-cot
# Layer 10
# Macro analysis
# Pearson correlation: -0.15 (p-value: 4.577e-01)
# Spearman correlation: -0.22 (p-value: 2.640e-01)
#
# GSM8K / Llama-3.1-8B-Instruct / zero-shot-cot
# Layer 11
# Macro analysis
# Pearson correlation: -0.15 (p-value: 4.416e-01)
# Spearman correlation: -0.23 (p-value: 2.310e-01)
#
# GSM8K / Llama-3.1-8B-Instruct / zero-shot-cot
# Layer 12
# Macro analysis
# Pearson correlation: -0.20 (p-value: 3.038e-01)
# Spearman correlation: -0.29 (p-value: 1.375e-01)
#
# GSM8K / Llama-3.1-8B-Instruct / zero-shot-cot
# Layer 13
# Macro analysis
# Pearson correlation: -0.28 (p-value: 1.493e-01)
# Spearman correlation: -0.35 (p-value: 6.414e-02)
#
# GSM8K / Llama-3.1-8B-Instruct / zero-shot-cot
# Layer 14
# Macro analysis
# Pearson correlation: -0.18 (p-value: 3.672e-01)
# Spearman correlation: -0.25 (p-value: 2.006e-01)
#
# GSM8K / Llama-3.1-8B-Instruct / zero-shot-cot
# Layer 15
# Macro analysis
# Pearson correlation: -0.08 (p-value: 6.979e-01)
# Spearman correlation: -0.13 (p-value: 5.024e-01)
#
# GSM8K / Llama-3.1-8B-Instruct / zero-shot-cot
# Layer 16
# Macro analysis
# Pearson correlation: -0.06 (p-value: 7.593e-01)
# Spearman correlation: -0.08 (p-value: 6.972e-01)
#
# GSM8K / Llama-3.1-8B-Instruct / zero-shot-cot
# Layer 17
# Macro analysis
# Pearson correlation: -0.04 (p-value: 8.284e-01)
# Spearman correlation: -0.05 (p-value: 7.926e-01)
#
# GSM8K / Llama-3.1-8B-Instruct / zero-shot-cot
# Layer 18
# Macro analysis
# Pearson correlation: -0.03 (p-value: 8.823e-01)
# Spearman correlation: -0.05 (p-value: 7.862e-01)
#
# GSM8K / Llama-3.1-8B-Instruct / zero-shot-cot
# Layer 19
# Macro analysis
# Pearson correlation: -0.02 (p-value: 9.223e-01)
# Spearman correlation: -0.02 (p-value: 9.130e-01)
#
# GSM8K / Llama-3.1-8B-Instruct / zero-shot-cot
# Layer 20
# Macro analysis
# Pearson correlation: -0.04 (p-value: 8.514e-01)
# Spearman correlation: -0.04 (p-value: 8.313e-01)
#
# GSM8K / Llama-3.1-8B-Instruct / zero-shot-cot
# Layer 21
# Macro analysis
# Pearson correlation: -0.03 (p-value: 8.662e-01)
# Spearman correlation: -0.03 (p-value: 8.851e-01)
#
# GSM8K / Llama-3.1-8B-Instruct / zero-shot-cot
# Layer 22
# Macro analysis
# Pearson correlation: -0.03 (p-value: 8.982e-01)
# Spearman correlation: -0.03 (p-value: 8.758e-01)
#
# GSM8K / Llama-3.1-8B-Instruct / zero-shot-cot
# Layer 23
# Macro analysis
# Pearson correlation: -0.02 (p-value: 9.021e-01)
# Spearman correlation: -0.01 (p-value: 9.504e-01)
#
# GSM8K / Llama-3.1-8B-Instruct / zero-shot-cot
# Layer 24
# Macro analysis
# Pearson correlation: -0.02 (p-value: 9.053e-01)
# Spearman correlation: -0.01 (p-value: 9.504e-01)
#
# GSM8K / Llama-3.1-8B-Instruct / zero-shot-cot
# Layer 25
# Macro analysis
# Pearson correlation: -0.03 (p-value: 8.875e-01)
# Spearman correlation: -0.01 (p-value: 9.504e-01)
#
# GSM8K / Llama-3.1-8B-Instruct / zero-shot-cot
# Layer 26
# Macro analysis
# Pearson correlation: -0.02 (p-value: 9.151e-01)
# Spearman correlation: -0.01 (p-value: 9.735e-01)
#
# GSM8K / Llama-3.1-8B-Instruct / zero-shot-cot
# Layer 27
# Macro analysis
# Pearson correlation: -0.02 (p-value: 9.205e-01)
# Spearman correlation: 0.01 (p-value: 9.768e-01)
#
# GSM8K / Llama-3.1-8B-Instruct / zero-shot-cot
# Layer 28
# Macro analysis
# Pearson correlation: -0.02 (p-value: 9.275e-01)
# Spearman correlation: -0.00 (p-value: 9.989e-01)
#
# GSM8K / Llama-3.1-8B-Instruct / zero-shot-cot
# Layer 29
# Macro analysis
# Pearson correlation: -0.02 (p-value: 9.174e-01)
# Spearman correlation: -0.01 (p-value: 9.482e-01)
#
# GSM8K / Llama-3.1-8B-Instruct / zero-shot-cot
# Layer 30
# Macro analysis
# Pearson correlation: -0.01 (p-value: 9.494e-01)
# Spearman correlation: -0.00 (p-value: 9.923e-01)
#
# GSM8K / Llama-3.1-8B-Instruct / zero-shot-cot
# Layer 31
# Macro analysis
# Pearson correlation: 0.03 (p-value: 8.978e-01)
# Spearman correlation: -0.03 (p-value: 8.780e-01)
#
# [Errno 2] No such file or directory: '../../../results/GSM8K/Llama-3.1-8B-Instruct/few-shot_layer_wise_hidden_states.conf'
# GSM8K / Llama-3.1-8B-Instruct / few-shot-cot
# Layer 0
# Macro analysis
# Pearson correlation: -0.16 (p-value: 4.294e-01)
# Spearman correlation: -0.27 (p-value: 1.604e-01)
#
# GSM8K / Llama-3.1-8B-Instruct / few-shot-cot
# Layer 1
# Macro analysis
# Pearson correlation: -0.16 (p-value: 4.058e-01)
# Spearman correlation: -0.26 (p-value: 1.872e-01)
#
# GSM8K / Llama-3.1-8B-Instruct / few-shot-cot
# Layer 2
# Macro analysis
# Pearson correlation: -0.24 (p-value: 2.282e-01)
# Spearman correlation: -0.23 (p-value: 2.323e-01)
#
# GSM8K / Llama-3.1-8B-Instruct / few-shot-cot
# Layer 3
# Macro analysis
# Pearson correlation: -0.24 (p-value: 2.106e-01)
# Spearman correlation: -0.23 (p-value: 2.340e-01)
#
# GSM8K / Llama-3.1-8B-Instruct / few-shot-cot
# Layer 4
# Macro analysis
# Pearson correlation: -0.30 (p-value: 1.203e-01)
# Spearman correlation: -0.30 (p-value: 1.180e-01)
#
# GSM8K / Llama-3.1-8B-Instruct / few-shot-cot
# Layer 5
# Macro analysis
# Pearson correlation: -0.29 (p-value: 1.394e-01)
# Spearman correlation: -0.28 (p-value: 1.477e-01)
#
# GSM8K / Llama-3.1-8B-Instruct / few-shot-cot
# Layer 6
# Macro analysis
# Pearson correlation: -0.30 (p-value: 1.222e-01)
# Spearman correlation: -0.29 (p-value: 1.330e-01)
#
# GSM8K / Llama-3.1-8B-Instruct / few-shot-cot
# Layer 7
# Macro analysis
# Pearson correlation: -0.31 (p-value: 1.109e-01)
# Spearman correlation: -0.31 (p-value: 1.115e-01)
#
# GSM8K / Llama-3.1-8B-Instruct / few-shot-cot
# Layer 8
# Macro analysis
# Pearson correlation: -0.36 (p-value: 6.254e-02)
# Spearman correlation: -0.36 (p-value: 6.265e-02)
#
# GSM8K / Llama-3.1-8B-Instruct / few-shot-cot
# Layer 9
# Macro analysis
# Pearson correlation: -0.41 (p-value: 3.215e-02)
# Spearman correlation: -0.39 (p-value: 4.281e-02)
#
# GSM8K / Llama-3.1-8B-Instruct / few-shot-cot
# Layer 10
# Macro analysis
# Pearson correlation: -0.43 (p-value: 2.150e-02)
# Spearman correlation: -0.41 (p-value: 3.192e-02)
#
# GSM8K / Llama-3.1-8B-Instruct / few-shot-cot
# Layer 11
# Macro analysis
# Pearson correlation: -0.43 (p-value: 2.071e-02)
# Spearman correlation: -0.44 (p-value: 1.974e-02)
#
# GSM8K / Llama-3.1-8B-Instruct / few-shot-cot
# Layer 12
# Macro analysis
# Pearson correlation: -0.40 (p-value: 3.332e-02)
# Spearman correlation: -0.41 (p-value: 3.194e-02)
#
# GSM8K / Llama-3.1-8B-Instruct / few-shot-cot
# Layer 13
# Macro analysis
# Pearson correlation: -0.40 (p-value: 3.397e-02)
# Spearman correlation: -0.37 (p-value: 5.066e-02)
#
# GSM8K / Llama-3.1-8B-Instruct / few-shot-cot
# Layer 14
# Macro analysis
# Pearson correlation: -0.42 (p-value: 2.761e-02)
# Spearman correlation: -0.40 (p-value: 3.402e-02)
#
# GSM8K / Llama-3.1-8B-Instruct / few-shot-cot
# Layer 15
# Macro analysis
# Pearson correlation: -0.42 (p-value: 2.750e-02)
# Spearman correlation: -0.40 (p-value: 3.297e-02)
#
# GSM8K / Llama-3.1-8B-Instruct / few-shot-cot
# Layer 16
# Macro analysis
# Pearson correlation: -0.42 (p-value: 2.446e-02)
# Spearman correlation: -0.43 (p-value: 2.330e-02)
#
# GSM8K / Llama-3.1-8B-Instruct / few-shot-cot
# Layer 17
# Macro analysis
# Pearson correlation: -0.39 (p-value: 3.959e-02)
# Spearman correlation: -0.41 (p-value: 2.836e-02)
#
# GSM8K / Llama-3.1-8B-Instruct / few-shot-cot
# Layer 18
# Macro analysis
# Pearson correlation: -0.39 (p-value: 3.776e-02)
# Spearman correlation: -0.43 (p-value: 2.217e-02)
#
# GSM8K / Llama-3.1-8B-Instruct / few-shot-cot
# Layer 19
# Macro analysis
# Pearson correlation: -0.43 (p-value: 2.115e-02)
# Spearman correlation: -0.45 (p-value: 1.746e-02)
#
# GSM8K / Llama-3.1-8B-Instruct / few-shot-cot
# Layer 20
# Macro analysis
# Pearson correlation: -0.44 (p-value: 1.922e-02)
# Spearman correlation: -0.43 (p-value: 2.296e-02)
#
# GSM8K / Llama-3.1-8B-Instruct / few-shot-cot
# Layer 21
# Macro analysis
# Pearson correlation: -0.45 (p-value: 1.613e-02)
# Spearman correlation: -0.45 (p-value: 1.513e-02)
#
# GSM8K / Llama-3.1-8B-Instruct / few-shot-cot
# Layer 22
# Macro analysis
# Pearson correlation: -0.46 (p-value: 1.302e-02)
# Spearman correlation: -0.46 (p-value: 1.465e-02)
#
# GSM8K / Llama-3.1-8B-Instruct / few-shot-cot
# Layer 23
# Macro analysis
# Pearson correlation: -0.46 (p-value: 1.405e-02)
# Spearman correlation: -0.48 (p-value: 1.045e-02)
#
# GSM8K / Llama-3.1-8B-Instruct / few-shot-cot
# Layer 24
# Macro analysis
# Pearson correlation: -0.48 (p-value: 1.051e-02)
# Spearman correlation: -0.49 (p-value: 7.635e-03)
#
# GSM8K / Llama-3.1-8B-Instruct / few-shot-cot
# Layer 25
# Macro analysis
# Pearson correlation: -0.48 (p-value: 9.609e-03)
# Spearman correlation: -0.50 (p-value: 7.264e-03)
#
# GSM8K / Llama-3.1-8B-Instruct / few-shot-cot
# Layer 26
# Macro analysis
# Pearson correlation: -0.48 (p-value: 9.717e-03)
# Spearman correlation: -0.49 (p-value: 7.500e-03)
#
# GSM8K / Llama-3.1-8B-Instruct / few-shot-cot
# Layer 27
# Macro analysis
# Pearson correlation: -0.47 (p-value: 1.177e-02)
# Spearman correlation: -0.50 (p-value: 7.116e-03)
#
# GSM8K / Llama-3.1-8B-Instruct / few-shot-cot
# Layer 28
# Macro analysis
# Pearson correlation: -0.47 (p-value: 1.135e-02)
# Spearman correlation: -0.53 (p-value: 3.718e-03)
#
# GSM8K / Llama-3.1-8B-Instruct / few-shot-cot
# Layer 29
# Macro analysis
# Pearson correlation: -0.47 (p-value: 1.158e-02)
# Spearman correlation: -0.60 (p-value: 6.706e-04)
#
# GSM8K / Llama-3.1-8B-Instruct / few-shot-cot
# Layer 30
# Macro analysis
# Pearson correlation: -0.47 (p-value: 1.215e-02)
# Spearman correlation: -0.59 (p-value: 9.995e-04)
#
# GSM8K / Llama-3.1-8B-Instruct / few-shot-cot
# Layer 31
# Macro analysis
# Pearson correlation: -0.44 (p-value: 1.790e-02)
# Spearman correlation: -0.48 (p-value: 9.892e-03)

# %%
agg_corr_matrix = np.zeros((len(model_names), len(dataset_names), len(prompting_strategies), 6))

for i in range(len(model_names)):
    for j in range(len(dataset_names)):
        for k in range(len(prompting_strategies)):
            agg_corr_matrix[i][j][k][0] = corr_matrix[i][j][k].mean()
            agg_corr_matrix[i][j][k][1] = corr_matrix[i][j][k].std()
            agg_corr_matrix[i][j][k][2] = corr_matrix[i][j][k].min()
            agg_corr_matrix[i][j][k][3] = corr_matrix[i][j][k].max()
            agg_corr_matrix[i][j][k][4] = corr_matrix[i][j][k].argmin()
            agg_corr_matrix[i][j][k][5] = corr_matrix[i][j][k].argmax()

# %%
print('mean')
print(agg_corr_matrix[:,:,:,0])
print()

print('std')
print(agg_corr_matrix[:,:,:,1])
print()

print('min (best)')
print(agg_corr_matrix[:,:,:,2])
print()

print('argmin (best)')
print(agg_corr_matrix[:,:,:,4])
print()

print('max (worst)')
print(agg_corr_matrix[:,:,:,3])
print()

print('argmax (worst)')
print(agg_corr_matrix[:,:,:,5])
print()
# Out:
# mean
# [[[-0.53408073 -0.70535095 -0.32020576  0.        ]
#   [-0.36485402 -0.57703079 -0.59071586 -0.23680448]
#   [-0.41255926 -0.36752502 -0.20267659  0.16303725]
#   [ 0.         -0.35942561  0.         -0.50362384]]
#
#  [[-0.33402801 -0.35706433 -0.25541575  0.        ]
#   [-0.2537906  -0.39696294 -0.32867181 -0.19619476]
#   [-0.10794023 -0.1220619  -0.35652805 -0.30595691]
#   [ 0.         -0.11208958  0.         -0.40820752]]]
#
# std
# [[[0.14125284 0.11262076 0.17894259 0.        ]
#   [0.1258162  0.11374226 0.0917844  0.0386227 ]
#   [0.16137619 0.15401828 0.09256529 0.07963961]
#   [0.         0.13888996 0.         0.0696427 ]]
#
#  [[0.0895974  0.1353686  0.07136158 0.        ]
#   [0.11865015 0.12954246 0.115158   0.13732236]
#   [0.11696958 0.07837558 0.06635095 0.05466457]
#   [0.         0.1025006  0.         0.0955328 ]]]
#
# min (best)
# [[[-0.717676   -0.87535975 -0.56586768  0.        ]
#   [-0.52461375 -0.6923401  -0.74283813 -0.30904455]
#   [-0.87106527 -0.56649778 -0.38775749 -0.0472542 ]
#   [ 0.         -0.48221128  0.         -0.606968  ]]
#
#  [[-0.60484893 -0.55273991 -0.37258664  0.        ]
#   [-0.55604327 -0.60893453 -0.52395294 -0.34492199]
#   [-0.33690233 -0.32507967 -0.4924203  -0.4221999 ]
#   [ 0.         -0.35455171  0.         -0.6036961 ]]]
#
# argmin (best)
# [[[19. 10.  1.  0.]
#   [19. 21. 17. 31.]
#   [ 1. 26.  9.  0.]
#   [ 0. 13.  0. 18.]]
#
#  [[13. 14. 29.  0.]
#   [13. 13. 12. 22.]
#   [13.  0.  9.  2.]
#   [ 0. 13.  0. 29.]]]
#
# max (worst)
# [[[-0.15082988 -0.41158755 -0.05866236  0.        ]
#   [ 0.02660091 -0.28477489 -0.4401814  -0.15948443]
#   [-0.16684101 -0.07935481 -0.01405142  0.27991162]
#   [ 0.          0.05363985  0.         -0.34988416]]
#
#  [[-0.21229978  0.02233489 -0.11966048  0.        ]
#   [-0.10977122 -0.18363725 -0.13824255  0.06734191]
#   [ 0.05361628 -0.02556925 -0.18323903 -0.1401814 ]
#   [ 0.          0.00574949  0.         -0.23241173]]]
#
# argmax (worst)
# [[[ 2.  2. 31.  0.]
#   [ 2.  2.  0.  3.]
#   [ 2.  1. 31.  6.]
#   [ 0.  3.  0.  1.]]
#
#  [[19.  0.  2.  0.]
#   [19. 18.  8.  2.]
#   [18. 29.  2.  0.]
#   [ 0. 27.  0.  3.]]]
